# %%
import pandas as pd
import numpy as np
df=pd.read_csv('./data/지이인짜최종리뷰데이터.csv')

# %%
df.head()
# Out:
#    관광지                                               전체내용
# 0  경복궁  대한민국의 역사 : 대한민국의 역사가 잠들어 있는 곳. 서울을 방문했다면 꼭 방문해...
# 1  경복궁  국민이 공감하는 장소 : 경복궁은 국민들이 자주 찾는곳으로 작성자는 주말에 자주 가...
# 2  경복궁  산책하기 좋은 경복궁 : 날씨 좋은 날 종종 산책하러 경복궁에 가는데 마음이 편온해...
# 3  경복궁  Good : Goooooood 다 좋습니다 다음에 또 오고 싶네요 근처 관광지도많고...
# 4  경복궁  가족단위로 방문하기 좋은곳 : 요새 더더욱 코로나로 인해 사람 방문이 적음. 두자녀...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5236 entries, 0 to 5235
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   관광지     5236 non-null   object
#  1   전체내용    5236 non-null   object
# dtypes: object(2)
# memory usage: 81.9+ KB

# %%
import re
only_kor=re.compile('[^ ㄱ-ㅣ가-힣+]')
for i in range(len(df)):
    df.전체내용[i]=only_kor.sub('',df.전체내용[i])

# %%
df
# Out:
#               관광지                                               전체내용
# 0             경복궁  대한민국의 역사  대한민국의 역사가 잠들어 있는 곳 서울을 방문했다면 꼭 방문해야 ...
# 1             경복궁  국민이 공감하는 장소  경복궁은 국민들이 자주 찾는곳으로 작성자는 주말에 자주 가족...
# 2             경복궁  산책하기 좋은 경복궁  날씨 좋은 날 종종 산책하러 경복궁에 가는데 마음이 편온해지...
# 3             경복궁     다 좋습니다 다음에 또 오고 싶네요 근처 관광지도많고 먹을거리도많네요 서울올때...
# 4             경복궁  가족단위로 방문하기 좋은곳  요새 더더욱 코로나로 인해 사람 방문이 적음 두자녀 동...
# ...           ...                                                ...
# 5231  벌교 홍교, 대한다원  저는 녹차밭을 별로 기대하고 가지 않았습니다 처음에는 안 들리고 지나가려고 했었는데...
# 5232  벌교 홍교, 대한다원                                             보성 녹차밭
# 5233  벌교 홍교, 대한다원  참 멋지고 이쁘네요말로만듣고 이번에 가봤는데 좋았어요또 가보고싶었고요추천해요혼자갔는...
# 5234  벌교 홍교, 대한다원                                 비오는 겨울 풍경도 아름다운 다원
# 5235  벌교 홍교, 대한다원  비오는 겨울 다원 산책은 무모한 도전이었지만 또 다른 경험다우너의 초록색은 없지만 ...
#
# [5236 rows x 2 columns]

# %%
df2=pd.read_csv('./data/진짜최종 데이터.csv')
df2.dropna(axis=1,inplace=True)
df2.head()
# Out:
#                 여행지                   주소   행정구역   시군구           분류 트립어드바이저평점  \
# 0             63스퀘어      영등포구 63로 50, 서울    서울시  영등포구          건축물         4
# 1           BIFF 광장           중구 남포동, 부산  부산광역시    중구  즐길거리 & 랜드마크         4
# 2  SEA LIFE 부산아쿠아리움  해운대구 해운대해변로 266, 부산  부산광역시  해운대구          수족관         4
# 3          가야산 국립공원           경남 합천군 가야면   경상남도   합천군         국립공원       4.5
# 4               간월재          울주군 상북면, 울산  울산광역시   울주군           산림       4.5
#
#    카테고리      최종긍정      최종부정
# 0  랜드마크  0.792686  0.207314
# 1  랜드마크  0.544369  0.455631
# 2  랜드마크  0.714060  0.285940
# 3    공원  0.897052  0.102948
# 4     산  0.802439  0.197561

# %%
df2=df2[['여행지','카테고리']]
df2.head()
# Out:
#                 여행지  카테고리
# 0             63스퀘어  랜드마크
# 1           BIFF 광장  랜드마크
# 2  SEA LIFE 부산아쿠아리움  랜드마크
# 3          가야산 국립공원    공원
# 4               간월재     산

# %%
df
# Out:
# '63스퀘어'

# %% [markdown]
# # 전체 리뷰 워드클라우드

# %%
df
# Out:
#               관광지                                               전체내용
# 0             경복궁  대한민국의 역사  대한민국의 역사가 잠들어 있는 곳 서울을 방문했다면 꼭 방문해야 ...
# 1             경복궁  국민이 공감하는 장소  경복궁은 국민들이 자주 찾는곳으로 작성자는 주말에 자주 가족...
# 2             경복궁  산책하기 좋은 경복궁  날씨 좋은 날 종종 산책하러 경복궁에 가는데 마음이 편온해지...
# 3             경복궁     다 좋습니다 다음에 또 오고 싶네요 근처 관광지도많고 먹을거리도많네요 서울올때...
# 4             경복궁  가족단위로 방문하기 좋은곳  요새 더더욱 코로나로 인해 사람 방문이 적음 두자녀 동...
# ...           ...                                                ...
# 5231  벌교 홍교, 대한다원  저는 녹차밭을 별로 기대하고 가지 않았습니다 처음에는 안 들리고 지나가려고 했었는데...
# 5232  벌교 홍교, 대한다원                                             보성 녹차밭
# 5233  벌교 홍교, 대한다원  참 멋지고 이쁘네요말로만듣고 이번에 가봤는데 좋았어요또 가보고싶었고요추천해요혼자갔는...
# 5234  벌교 홍교, 대한다원                                 비오는 겨울 풍경도 아름다운 다원
# 5235  벌교 홍교, 대한다원  비오는 겨울 다원 산책은 무모한 도전이었지만 또 다른 경험다우너의 초록색은 없지만 ...
#
# [5236 rows x 2 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt # 시각화 패키지
# 데이터 전처리
from konlpy.tag import Okt
from collections import Counter

# %%
okt=Okt() # 형태소 분석기
word_list=[]
word_list=df['전체내용']

# %%
sentences_tag=[]

for sentence in word_list:
    morph=okt.pos(sentence)
    sentences_tag.append(morph)

# %%
sentences_tag
# Out:
# [[('대한민국', 'Noun'),
#   ('의', 'Josa'),
#   ('역사', 'Noun'),
#   ('대한민국', 'Noun'),
#   ('의', 'Josa'),
#   ('역사', 'Noun'),
#   ('가', 'Josa'),
#   ('잠들어', 'Verb'),
#   ('있는', 'Adjective'),
#   ('곳', 'Noun'),
#   ('서울', 'Noun'),
#   ('을', 'Josa'),
#   ('방문', 'Noun'),
#   ('했다면', 'Verb'),
#   ('꼭', 'Noun'),
#   ('방문', 'Noun'),
#   ('해야', 'Verb'),
#   ('되는', 'Verb'),
#   ('곳', 'Noun'),
#   ('경복궁', 'Noun'),
#   ('은', 'Josa'),
#   ('우리', 'Noun'),
#   ('의', 'Josa'),
#   ('역사', 'Noun'),
#   ('다', 'Josa'),
#   ('넓은', 'Adjective'),
#   ('경복궁', 'Noun'),
#   ('을', 'Josa'),
#   ('산책', 'Noun'),
#   ('할', 'Verb'),
#   ('수', 'Noun'),
#   ('있는', 'Adjective'),
#   ('것', 'Noun'),
#   ('은', 'Josa'),
#   ('언제나', 'Adverb'),
#   ('행복', 'Noun'),
#   ('이다', 'Josa')],
#  [('국민', 'Noun'),
#   ('이', 'Josa'),
#   ('공감', 'Noun'),
#   ('하는', 'Verb'),
#   ('장소', 'Noun'),
#   ('경복궁', 'Noun'),
#   ('은', 'Josa'),
#   ('국민', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('자주', 'Noun'),
#   ('찾는', 'Verb'),
#   ('곳', 'Noun'),
#   ('으로', 'Josa'),
#   ('작성자', 'Noun'),
#   ('는', 'Josa'),
#   ('주말', 'Noun'),
#   ('에', 'Josa'),
#   ('자주', 'Noun'),
#   ('가족', 'Noun'),
#   ('들', 'Suffix'),
#   ('과', 'Josa'),
#   ('방문', 'Noun'),
#   ('하고', 'Josa'),
#   ('있음', 'Adjective'),
#   ('특히', 'Adverb'),
#   ('가족', 'Noun'),
#   ('들', 'Suffix'),
#   ('과', 'Josa'),
#   ('방문', 'Noun'),
#   ('시', 'Noun'),
#   ('옛', 'Modifier'),
#   ('고궁', 'Noun'),
#   ('의', 'Josa'),
#   ('멋', 'Noun'),
#   ('을', 'Josa'),
#   ('즐길수', 'Verb'),
#   ('있으며', 'Adjective'),
#   ('쾌적한', 'Adjective'),
#   ('공기', 'Noun'),
#   ('와', 'Josa'),
#   ('역사', 'Noun'),
#   ('를', 'Josa'),
#   ('체험', 'Noun'),
#   ('하고', 'Josa'),
#   ('힐링', 'Noun'),
#   ('할수', 'Verb'),
#   ('있는', 'Adjective'),
#   ('곳임', 'Noun')],
#  [('산책', 'Noun'),
#   ('하기', 'Verb'),
#   ('좋은', 'Adjective'),
#   ('경복궁', 'Noun'),
#   ('날씨', 'Noun'),
#   ('좋은', 'Adjective'),
#   ('날', 'Noun'),
#   ('종종', 'Noun'),
#   ('산책', 'Noun'),
#   ('하러', 'Verb'),
#   ('경복궁', 'Noun'),
#   ('에', 'Josa'),
#   ('가는데', 'Verb'),
#   ('마음', 'Noun'),
#   ('이', 'Josa'),
#   ('편', 'Noun'),
#   ('온', 'Modifier'),
#   ('해지', 'Noun'),
#   ('는', 'Josa'),
#   ('기분', 'Noun'),
#   ('이라고', 'Josa'),
#   ('할까', 'Verb'),
#   ('요', 'Noun'),
#   ('특히', 'Adverb'),
#   ('봄', 'Noun'),
#   ('이나', 'Josa'),
#   ('가을', 'Noun'),
#   ('에', 'Josa'),
#   ('산책', 'Noun'),
#   ('가는', 'Verb'),
#   ('걸', 'Noun'),
#   ('추천', 'Noun'),
#   ('해요', 'Verb')],
#  [('다', 'Adverb'),
#   ('좋습니다', 'Adjective'),
#   ('다음', 'Noun'),
#   ('에', 'Josa'),
#   ('또', 'Noun'),
#   ('오고', 'Verb'),
#   ('싶네요', 'Verb'),
#   ('근처', 'Noun'),
#   ('관광지', 'Noun'),
#   ('도', 'Josa'),
#   ('많고', 'Adjective'),
#   ('먹을', 'Verb'),
#   ('거리', 'Noun'),
#   ('도', 'Josa'),
#   ('많네요', 'Adjective'),
#   ('서', 'Modifier'),
#   ('울', 'Modifier'),
#   ('올', 'Modifier'),
#   ('때', 'Noun'),
#   ('마다', 'Josa'),
#   ('자주', 'Noun'),
#   ('이용', 'Noun'),
#   ('중', 'Suffix'),
#   ('인데', 'Josa'),
#   ('또', 'Noun'),
#   ('오고싶습니다', 'Verb')],
#  [('가족', 'Noun'),
#   ('단', 'Modifier'),
#   ('위로', 'Noun'),
#   ('방문', 'Noun'),
#   ('하기', 'Verb'),
#   ('좋은', 'Adjective'),
#   ('곳', 'Noun'),
#   ('요새', 'Noun'),
#   ('더', 'Noun'),
#   ('더욱', 'Noun'),
#   ('코로나', 'Noun'),
#   ('로', 'Josa'),
#   ('인해', 'Adjective'),
#   ('사람', 'Noun'),
#   ('방문', 'Noun'),
#   ('이', 'Josa'),
#   ('적음', 'Verb'),
#   ('두', 'Determiner'),
#   ('자녀', 'Noun'),
#   ('동', 'Modifier'),
#   ('반시', 'Noun'),
#   ('성인', 'Noun'),
#   ('입장', 'Noun'),
#   ('무료', 'Noun'),
#   ('지금', 'Noun'),
#   ('시기', 'Noun'),
#   ('에', 'Josa'),
#   ('나들이', 'Noun'),
#   ('하기', 'Verb'),
#   ('딱', 'Adverb'),
#   ('좋은', 'Adjective'),
#   ('곳', 'Noun'),
#   ('지하철', 'Noun'),
#   ('광화문역', 'Noun'),
#   ('이나', 'Josa'),
#   ('종각역', 'Noun'),
#   ('이용', 'Noun'),
#   ('편리', 'Noun')],
#  [('하늘', 'Noun'),
#   ('이', 'Josa'),
#   ('내린', 'Verb'),
#   ('큰', 'Verb'),
#   ('복', 'Noun'),
#   ('조선', 'Noun'),
#   ('개국', 'Noun'),
#   ('년', 'Noun'),
#   ('째', 'Suffix'),
#   ('인', 'Josa'),
#   ('년', 'Noun'),
#   ('에', 'Josa'),
#   ('처음', 'Noun'),
#   ('으로', 'Josa'),
#   ('세운', 'Noun'),
#   ('으뜸', 'Noun'),
#   ('궁궐', 'Noun'),
#   ('이다', 'Josa'),
#   ('하늘', 'Noun'),
#   ('이', 'Josa'),
#   ('내린', 'Verb'),
#   ('큰', 'Verb'),
#   ('복', 'Noun'),
#   ('이라는', 'Josa'),
#   ('뜻', 'Noun'),
#   ('으로', 'Josa'),
#   ('경복궁', 'Noun'),
#   ('이라', 'Josa'),
#   ('이름지었다가', 'Verb'),
#   ('장', 'Noun'),
#   ('아름답고', 'Adjective'),
#   ('웅장', 'Noun'),
#   ('한', 'Josa'),
#   ('이', 'Noun'),
#   ('경복궁', 'Noun'),
#   ('은', 'Josa'),
#   ('임진왜란', 'Noun'),
#   ('일제강점기', 'Noun'),
#   ('번', 'Noun'),
#   ('에', 'Josa'),
#   ('걸쳐', 'Verb'),
#   ('일본', 'Noun'),
#   ('의', 'Josa'),
#   ('악랄하고', 'Adjective'),
#   ('잔인한', 'Adjective'),
#   ('파괴', 'Noun'),
#   ('를', 'Josa'),
#   ('당한', 'Noun'),
#   ('악연', 'Noun'),
#   ('을', 'Josa'),
#   ('갖고있다', 'Verb'),
#   ('향원정', 'Noun'),
#   ('은', 'Josa'),
#   ('보수', 'Noun'),
#   ('공사', 'Noun'),
#   ('로', 'Josa'),
#   ('인해', 'Adjective'),
#   ('볼', 'Noun'),
#   ('수', 'Noun'),
#   ('없지만', 'Adjective'),
#   ('아름다운', 'Adjective'),
#   ('경회루', 'Noun'),
#   ('만으로도', 'Josa'),
#   ('충분한', 'Adjective'),
#   ('경복궁', 'Noun'),
#   ('이다', 'Josa')],
#  [('굿', 'Noun'),
#   ('한국', 'Noun'),
#   ('건축물', 'Noun'),
#   ('의', 'Josa'),
#   ('아름다', 'Adjective'),
#   ('움', 'Noun'),
#   ('을', 'Josa'),
#   ('느낄', 'Verb'),
#   ('수', 'Noun'),
#   ('있는', 'Adjective'),
#   ('곳', 'Noun'),
#   ('이고', 'Josa'),
#   ('한복', 'Noun'),
#   ('을', 'Josa'),
#   ('입었을', 'Verb'),
#   ('때', 'Noun'),
#   ('입장료', 'Noun'),
#   ('는', 'Josa'),
#   ('무료', 'Noun'),
#   ('주변', 'Noun'),
#   ('에', 'Josa'),
#   ('한복', 'Noun'),
#   ('대', 'Modifier'),
#   ('여', 'Modifier'),
#   ('점', 'Noun'),
#   ('이', 'Josa'),
#   ('많으니', 'Adjective'),
#   ('한번', 'Noun'),
#   ('쯤', 'Suffix'),
#   ('대여', 'Noun'),
#   ('해서', 'Verb'),
#   ('입어보는것도', 'Verb'),
#   ('나쁘지', 'Adjective'),
#   ('않을듯', 'Verb')],
#  [('조선', 'Noun'),
#   ('의', 'Josa'),
#   ('집', 'Noun'),
#   ('조선', 'Noun'),
#   ('의', 'Josa'),
#   ('성곽', 'Noun'),
#   ('안', 'Noun'),
#   ('에는', 'Josa'),
#   ('박물관', 'Noun'),
#   ('도', 'Josa'),
#   ('있고', 'Adjective'),
#   ('경회루', 'Noun'),
#   ('등', 'Noun'),
#   ('볼것이', 'Verb'),
#   ('많다', 'Adjective'),
#   ('외국', 'Noun'),
#   ('인들', 'Josa'),
#   ('및', 'Noun'),
#   ('연인', 'Noun'),
#   ('들', 'Suffix'),
#   ('도', 'Josa'),
#   ('주변', 'Noun'),
#   ('에서', 'Josa'),
#   ('한복', 'Noun'),
#   ('및', 'Noun'),
#   ('특수', 'Noun'),
#   ('복장', 'Noun'),
#   ('빌려서', 'Verb'),
#   ('성', 'Noun'),
#   ('을', 'Josa'),
#   ('둘러보며', 'Verb'),
#   ('데이트', 'Noun'),
#   ('를', 'Josa'),
#   ('즐기기에', 'Verb'),
#   ('딱', 'Adverb'),
#   ('좋다', 'Adjective'),
#   ('야간', 'Noun'),
#   ('개장', 'Noun'),
#   ('도', 'Josa'),
#   ('하니', 'Noun'),
#   ('잘', 'Verb'),
#   ('알아보고', 'Verb'),
#   ('올것', 'Verb'),
#   ('한국', 'Noun'),
#   ('사람', 'Noun'),
#   ('이', 'Josa'),
#   ('라면', 'Noun'),
#   ('한번', 'Noun'),
#   ('이상은', 'Noun'),
#   ('꼭', 'Noun'),
#   ('와', 'Josa'),
#   ('봤고', 'Verb'),
#   ('외국인', 'Noun'),
#   ('들', 'Suffix'),
#   ('에게도', 'Josa'),
#   ('좋은', 'Adjective'),
#   ('관광지', 'Noun'),
#   ('라고', 'Josa'),
#   ('생각', 'Noun'),
#   ('한다', 'Verb'),
#   ('앞', 'Noun'),
#   ('에', 'Josa'),
#   ('광화문', 'Noun'),
#   ('광장', 'Noun'),
#   ('청계천', 'Noun'),
#   ('뒤', 'Noun'),
#   ('로', 'Josa'),
#   ('삼청동', 'Noun'),
#   ('이', 'Determiner'),
#   ('주변', 'Noun'),
#   ('에', 'Josa'),
#   ('연', 'Modifier'),
#   ('계', 'Noun'),
#   ('된', 'Verb'),
#   ('명소', 'Noun'),
#   ('들', 'Suffix'),
#   ('도', 'Josa'),
#   ('많기', 'Adjective'),
#   ('때문', 'Noun'),
#   ('에', 'Josa'),
#   ('꼭', 'Noun'),
#   ('추천', 'Noun'),
#   ('한다', 'Verb')],
#  [('대표', 'Noun'),
#   ('문화재', 'Noun'),
#   ('대부분', 'Noun'),
#   ('의', 'Josa'),
#   ('사람', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('여행', 'Noun'),
#   ('을', 'Josa'),
#   ('간다', 'Noun'),
#   ('면', 'Josa'),
#   ('그', 'Noun'),
#   ('나라', 'Noun'),
#   ('의', 'Josa'),
#   ('유서', 'Noun'),
#   ('깊은', 'Adjective'),
#   ('궁전', 'Noun'),
#   ('을', 'Josa'),
#   ('찾게', 'Verb'),
#   ('된다', 'Verb'),
#   ('한국', 'Noun'),
#   ('에서는', 'Josa'),
#   ('그', 'Noun'),
#   ('곳', 'Noun'),
#   ('이', 'Josa'),
#   ('바로', 'Noun'),
#   ('경복궁', 'Noun'),
#   ('이다', 'Josa'),
#   ('지금', 'Noun'),
#   ('의', 'Josa'),
#   ('경복궁', 'Noun'),
#   ('은', 'Josa'),
#   ('원래', 'Noun'),
#   ('의', 'Josa'),
#   ('것', 'Noun'),
#   ('보다', 'Josa'),
#   ('많이', 'Adverb'),
#   ('축소', 'Noun'),
#   ('되었지만', 'Verb'),
#   ('그래도', 'Adverb'),
#   ('깨끗이', 'Adverb'),
#   ('잘', 'Verb'),
#   ('정돈', 'Noun'),
#   ('되어', 'Verb'),
#   ('있으며', 'Adjective'),
#   ('위엄', 'Noun'),
#   ('이', 'Josa'),
#   ('있다', 'Adjective')],
#  [('경복궁', 'Noun'),
#   ('몇번', 'Noun'),
#   ('을', 'Josa'),
#   ('가도', 'Noun'),
#   ('감탄', 'Noun'),
#   ('하게', 'Verb'),
#   ('되며', 'Verb'),
#   ('산책', 'Noun'),
#   ('하기', 'Verb'),
#   ('최고', 'Noun'),
#   ('인', 'Josa'),
#   ('경복궁', 'Noun'),
#   ('매번', 'Noun'),
#   ('갈', 'Verb'),
#   ('때', 'Noun'),
#   ('마다', 'Josa'),
#   ('정교함과', 'Adjective'),
#   ('운치', 'Noun'),
#   ('에', 'Josa'),
#   ('또한', 'Modifier'),
#   ('번', 'Noun'),
#   ('반하게', 'Adjective'),
#   ('되는', 'Verb'),
#   ('곳', 'Noun'),
#   ('주변', 'Noun'),
#   ('에', 'Josa'),
#   ('볼거리', 'Noun'),
#   ('도', 'Josa'),
#   ('많음', 'Adjective')],
#  [('기대', 'Noun'),
#   ('이상', 'Noun'),
#   ('만족', 'Noun'),
#   ('저번', 'Noun'),
#   ('달', 'Noun'),
#   ('에', 'Josa'),
#   ('아주', 'Noun'),
#   ('오랜', 'Modifier'),
#   ('만', 'Noun'),
#   ('에', 'Josa'),
#   ('다시', 'Noun'),
#   ('방문', 'Noun'),
#   ('년', 'Noun'),
#   ('만에', 'Josa'),
#   ('재', 'Noun'),
#   ('방문', 'Noun'),
#   ('인데', 'Josa'),
#   ('그', 'Determiner'),
#   ('사이', 'Noun'),
#   ('에', 'Josa'),
#   ('카페나', 'Noun'),
#   ('작은', 'Adjective'),
#   ('상점', 'Noun'),
#   ('옷가게', 'Noun'),
#   ('가', 'Josa'),
#   ('눈', 'Noun'),
#   ('에', 'Josa'),
#   ('많이', 'Adverb'),
#   ('띄었다', 'Verb'),
#   ('서울내에', 'Verb'),
#   ('한', 'Determiner'),
#   ('옥', 'Noun'),
#   ('건물', 'Noun'),
#   ('제발', 'Noun'),
#   ('보존', 'Noun'),
#   ('해주세요', 'Verb')],
#  [('삼청동', 'Noun'),
#   ('길', 'Noun'),
#   ('삼청동', 'Noun'),
#   ('길', 'Noun'),
#   ('한', 'Determiner'),
#   ('옥', 'Noun'),
#   ('건물', 'Noun'),
#   ('들', 'Suffix'),
#   ('을', 'Josa'),
#   ('볼수있는', 'Verb'),
#   ('거리', 'Noun'),
#   ('중', 'Suffix'),
#   ('한', 'Determiner'),
#   ('곳', 'Noun'),
#   ('다만', 'Noun'),
#   ('예전', 'Noun'),
#   ('에', 'Josa'),
#   ('비해', 'Verb'),
#   ('상권', 'Noun'),
#   ('이', 'Josa'),
#   ('많이', 'Adverb'),
#   ('없어졌어요', 'Verb'),
#   ('그래도', 'Adverb'),
#   ('걸으면서', 'Verb'),
#   ('구경', 'Noun'),
#   ('하기에는', 'Verb'),
#   ('좋아요', 'Adjective')],
#  [('전통', 'Noun'),
#   ('과', 'Josa'),
#   ('현대', 'Noun'),
#   ('의', 'Josa'),
#   ('건축', 'Noun'),
#   ('양식', 'Noun'),
#   ('의', 'Josa'),
#   ('조합', 'Noun'),
#   ('이', 'Josa'),
#   ('주는', 'Verb'),
#   ('이색', 'Noun'),
#   ('적', 'Suffix'),
#   ('인', 'Josa'),
#   ('도시', 'Noun'),
#   ('풍경', 'Noun'),
#   ('이', 'Noun'),
#   ('곳', 'Noun'),
#   ('에서는', 'Josa'),
#   ('기와', 'Noun'),
#   ('나', 'Josa'),
#   ('목재', 'Noun'),
#   ('등', 'Noun'),
#   ('을', 'Josa'),
#   ('이용', 'Noun'),
#   ('해', 'Verb'),
#   ('한국', 'Noun'),
#   ('의', 'Josa'),
#   ('전통', 'Noun'),
#   ('적', 'Suffix'),
#   ('인', 'Josa'),
#   ('느낌', 'Noun'),
#   ('을', 'Josa'),
#   ('살린', 'Verb'),
#   ('현대', 'Noun'),
#   ('식', 'Suffix'),
#   ('건물', 'Noun'),
#   ('이', 'Josa'),
#   ('많아서', 'Adjective'),
#   ('이색', 'Noun'),
#   ('적', 'Suffix'),
#   ('인', 'Josa'),
#   ('도시', 'Noun'),
#   ('풍경', 'Noun'),
#   ('을', 'Josa'),
#   ('감상', 'Noun'),
#   ('할', 'Verb'),
#   ('수', 'Noun'),
#   ('있다', 'Adjective'),
#   ('걷기', 'Noun'),
#   ('만', 'Josa'),
#   ('해도', 'Noun'),
#   ('재미있다', 'Adjective')],
#  [('옛', 'Adverb'),
#   ('명성', 'Noun'),
#   ('은', 'Josa'),
#   ('어디', 'Noun'),
#   ('로', 'Josa'),
#   ('삼청동', 'Noun'),
#   ('팥죽', 'Noun'),
#   ('맛집', 'Noun'),
#   ('서울', 'Noun'),
#   ('에서', 'Josa'),
#   ('두번째', 'Noun'),
#   ('로', 'Josa'),
#   ('맛있는', 'Adjective'),
#   ('집', 'Noun'),
#   ('을', 'Josa'),
#   ('찾아', 'Verb'),
#   ('가면', 'Noun'),
#   ('서', 'Josa'),
#   ('삼청동', 'Noun'),
#   ('메인', 'Noun'),
#   ('거리', 'Noun'),
#   ('를', 'Josa'),
#   ('걸으면서', 'Verb'),
#   ('곳곳', 'Noun'),
#   ('에', 'Josa'),
#   ('임대', 'Noun'),
#   ('표시', 'Noun'),
#   ('가', 'Josa'),
#   ('되어', 'Verb'),
#   ('있는', 'Adjective'),
#   ('빈', 'Noun'),
#   ('가게', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('너무', 'Adverb'),
#   ('많이', 'Adverb'),
#   ('생긴', 'Verb'),
#   ('것', 'Noun'),
#   ('을', 'Josa'),
#   ('보고', 'Noun'),
#   ('놀랐다', 'Verb'),
#   ('이', 'Determiner'),
#   ('곳도', 'Noun'),
#   ('젠트리피케이션', 'Noun'),
#   ('때문', 'Noun'),
#   ('에', 'Josa'),
#   ('자영', 'Noun'),
#   ('업자', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('어려움', 'Noun'),
#   ('을', 'Josa'),
#   ('겪고', 'Verb'),
#   ('있는', 'Adjective'),
#   ('것', 'Noun'),
#   ('같은데', 'Adjective'),
#   ('우리나라', 'Noun'),
#   ('대표', 'Noun'),
#   ('적', 'Suffix'),
#   ('인', 'Josa'),
#   ('관광지', 'Noun'),
#   ('인', 'Josa'),
#   ('궁', 'Noun'),
#   ('인근', 'Noun'),
#   ('에', 'Josa'),
#   ('있어', 'Adjective'),
#   ('우리나라', 'Noun'),
#   ('전통', 'Noun'),
#   ('공예품', 'Noun'),
#   ('을', 'Josa'),
#   ('판매', 'Noun'),
#   ('하는', 'Verb'),
#   ('상가', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('번성', 'Noun'),
#   ('하면', 'Verb'),
#   ('좋을텐데', 'Adjective'),
#   ('아쉬움', 'Noun'),
#   ('이', 'Josa'),
#   ('너무', 'Adverb'),
#   ('컸다', 'Verb')],
#  [('옛날', 'Noun'),
#   ('에', 'Josa'),
#   ('비해', 'Verb'),
#   ('많이', 'Adverb'),
#   ('변한', 'Adjective'),
#   ('예전', 'Noun'),
#   ('엔', 'Josa'),
#   ('갈만', 'Verb'),
#   ('한', 'Determiner'),
#   ('식당', 'Noun'),
#   ('과', 'Josa'),
#   ('카페', 'Noun'),
#   ('를', 'Josa'),
#   ('줄줄이', 'Noun'),
#   ('알았는데', 'Verb'),
#   ('요즘', 'Noun'),
#   ('은', 'Josa'),
#   ('정보', 'Noun'),
#   ('가', 'Josa'),
#   ('없다', 'Adjective'),
#   ('그래도', 'Adverb'),
#   ('갈', 'Verb'),
#   ('때', 'Noun'),
#   ('마다', 'Josa'),
#   ('옛', 'Adverb'),
#   ('추억', 'Noun'),
#   ('때문', 'Noun'),
#   ('인지', 'Josa'),
#   ('정겹고', 'Adjective'),
#   ('좋았다', 'Adjective'),
#   ('사람', 'Noun'),
#   ('이', 'Josa'),
#   ('많이', 'Adverb'),
#   ('없어서', 'Adjective'),
#   ('여유롭게', 'Verb'),
#   ('가기', 'Noun'),
#   ('좋은', 'Adjective'),
#   ('곳', 'Noun')],
#  [('퇴근', 'Noun'),
#   ('후', 'Noun'),
#   ('데이트', 'Noun'),
#   ('코스', 'Noun'),
#   ('로', 'Josa'),
#   ('좋은', 'Adjective'),
#   ('길', 'Noun'),
#   ('퇴근', 'Noun'),
#   ('후', 'Noun'),
#   ('데이트', 'Noun'),
#   ('코스', 'Noun'),
#   ('로', 'Josa'),
#   ('좋은', 'Adjective'),
#   ('길', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('비교', 'Noun'),
#   ('적', 'Suffix'),
#   ('중심부', 'Noun'),
#   ('에', 'Josa'),
#   ('위치', 'Noun'),
#   ('해', 'Verb'),
#   ('있으며', 'Adjective'),
#   ('저녁', 'Noun'),
#   ('에', 'Josa'),
#   ('데이트', 'Noun'),
#   ('목적', 'Noun'),
#   ('으로', 'Josa'),
#   ('방문', 'Noun'),
#   ('하는', 'Verb'),
#   ('분', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('많습니다', 'Adjective'),
#   ('정독', 'Noun'),
#   ('도서관', 'Noun'),
#   ('부터', 'Josa'),
#   ('시작', 'Noun'),
#   ('해', 'Verb'),
#   ('식사', 'Noun'),
#   ('후', 'Noun'),
#   ('걷기', 'Noun'),
#   ('에도', 'Josa'),
#   ('괜찮습니다', 'Adjective')],
#  [('봄', 'Noun'),
#   ('가을', 'Noun'),
#   ('방문', 'Noun'),
#   ('강추', 'Noun'),
#   ('삼청동', 'Noun'),
#   ('길', 'Noun'),
#   ('방문', 'Noun'),
#   ('한지', 'Noun'),
#   ('얼마', 'Noun'),
#   ('되지', 'Verb'),
#   ('않았어요', 'Verb'),
#   ('길은', 'Adjective'),
#   ('좁고', 'Adjective'),
#   ('다니기', 'Verb'),
#   ('불편하지만', 'Adjective'),
#   ('한', 'Determiner'),
#   ('옥', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('몰려있고', 'Verb'),
#   ('한', 'Determiner'),
#   ('옥', 'Noun'),
#   ('카페', 'Noun'),
#   ('를', 'Josa'),
#   ('즐길수있어', 'Verb'),
#   ('좋았습니다', 'Adjective'),
#   ('더군다나', 'Noun'),
#   ('루프', 'Noun'),
#   ('탑', 'Noun'),
#   ('의', 'Josa'),
#   ('카페', 'Noun'),
#   ('가', 'Josa'),
#   ('많아', 'Adjective'),
#   ('좋았어요', 'Adjective'),
#   ('여유', 'Noun'),
#   ('를', 'Josa'),
#   ('제대로', 'Noun'),
#   ('느끼실수있습니다', 'Verb'),
#   ('그리고', 'Conjunction'),
#   ('수', 'Modifier'),
#   ('제비집', 'Noun'),
#   ('유명해요', 'Adjective'),
#   ('꼭', 'Noun'),
#   ('방문', 'Noun'),
#   ('해서', 'Verb'),
#   ('드셔', 'Verb'),
#   ('보시길', 'Verb'),
#   ('짱', 'Modifier'),
#   ('맛', 'Noun')],
#  [('삼청동', 'Noun'),
#   ('길', 'Noun'),
#   ('외국인', 'Noun'),
#   ('이', 'Josa'),
#   ('많이', 'Adverb'),
#   ('찾아오는', 'Verb'),
#   ('삼청동', 'Noun'),
#   ('길', 'Noun'),
#   ('주말', 'Noun'),
#   ('에는', 'Josa'),
#   ('국내', 'Noun'),
#   ('여행객', 'Noun'),
#   ('들', 'Suffix'),
#   ('까지', 'Josa'),
#   ('있어', 'Adjective'),
#   ('걷기', 'Noun'),
#   ('힘들', 'Adjective'),
#   ('때', 'Noun'),
#   ('도', 'Josa'),
#   ('있다', 'Adjective'),
#   ('인기', 'Noun'),
#   ('있는', 'Adjective'),
#   ('골목길', 'Noun'),
#   ('말고', 'Josa'),
#   ('조용하게', 'Adjective'),
#   ('산책', 'Noun'),
#   ('할', 'Verb'),
#   ('수', 'Noun'),
#   ('있는', 'Adjective'),
#   ('코스', 'Noun'),
#   ('도', 'Josa'),
#   ('있으니', 'Adjective'),
#   ('잘', 'Verb'),
#   ('찾아보면', 'Verb'),
#   ('좋다', 'Adjective')],
#  [('한국', 'Noun'),
#   ('적', 'Suffix'),
#   ('인', 'Josa'),
#   ('분위기', 'Noun'),
#   ('가', 'Josa'),
#   ('아름다운', 'Adjective'),
#   ('곳', 'Noun'),
#   ('봄되', 'Verb'),
#   ('면', 'Noun'),
#   ('꼭', 'Noun'),
#   ('가는', 'Verb'),
#   ('삼청동', 'Noun'),
#   ('곳곳', 'Noun'),
#   ('에', 'Josa'),
#   ('예쁜', 'Adjective'),
#   ('상점', 'Noun'),
#   ('들', 'Suffix'),
#   ('도', 'Josa'),
#   ('있고', 'Adjective'),
#   ('맛있는', 'Adjective'),
#   ('한식', 'Noun'),
#   ('집', 'Noun'),
#   ('이', 'Josa'),
#   ('많다', 'Adjective'),
#   ('사진', 'Noun'),
#   ('찍기', 'Noun'),
#   ('도', 'Josa'),
#   ('좋고', 'Adjective'),
#   ('그냥', 'Noun'),
#   ('산책', 'Noun'),
#   ('하는', 'Verb'),
#   ('것', 'Noun'),
#   ('만으로도', 'Josa'),
#   ('기분', 'Noun'),
#   ('좋은', 'Adjective'),
#   ('곳', 'Noun')],
#  [('데이트', 'Noun'),
#   ('장소', 'Noun'),
#   ('로', 'Josa'),
#   ('추천', 'Noun'),
#   ('데이트', 'Noun'),
#   ('장소', 'Noun'),
#   ('로', 'Josa'),
#   ('추천', 'Noun'),
#   ('받는', 'Verb'),
#   ('곳', 'Noun'),
#   ('들', 'Suffix'),
#   ('중', 'Noun'),
#   ('하나로', 'Noun'),
#   ('다양한', 'Adjective'),
#   ('볼거리', 'Noun'),
#   ('와', 'Josa'),
#   ('음식', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('있는', 'Adjective'),
#   ('곳', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('여기', 'Noun'),
#   ('떡볶이', 'Noun'),
#   ('집', 'Noun'),
#   ('이', 'Josa'),
#   ('아주', 'Noun'),
#   ('유명하여', 'Adjective'),
#   ('줄', 'Noun'),
#   ('을', 'Josa'),
#   ('섭니다', 'Verb')],
#  [('어제', 'Noun'),
#   ('다녀온', 'Verb'),
#   ('인사동', 'Noun'),
#   ('코로나', 'Noun'),
#   ('때문', 'Noun'),
#   ('인지', 'Josa'),
#   ('인사동', 'Noun'),
#   ('거리', 'Noun'),
#   ('에는', 'Josa'),
#   ('사람', 'Noun'),
#   ('의', 'Josa'),
#   ('수', 'Noun'),
#   ('는', 'Josa'),
#   ('어느', 'Modifier'),
#   ('정도', 'Noun'),
#   ('있긴', 'Adjective'),
#   ('했지만', 'Verb'),
#   ('무척', 'Noun'),
#   ('이나', 'Josa'),
#   ('한산했다', 'Adjective'),
#   ('아마도', 'Adverb'),
#   ('영업', 'Noun'),
#   ('하는', 'Verb'),
#   ('상점', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('많이', 'Adverb'),
#   ('문', 'Noun'),
#   ('을', 'Josa'),
#   ('닫은것', 'Verb'),
#   ('때문', 'Noun'),
#   ('이', 'Josa'),
#   ('아닌가', 'Adjective'),
#   ('싶다', 'Verb'),
#   ('커플', 'Noun'),
#   ('이', 'Determiner'),
#   ('라면', 'Noun'),
#   ('차', 'Noun'),
#   ('한잔', 'Noun'),
#   ('마시면서', 'Verb'),
#   ('분', 'Noun'),
#   ('정도', 'Noun'),
#   ('갈으면서', 'Verb'),
#   ('즐길수', 'Verb'),
#   ('있는', 'Adjective'),
#   ('분위기', 'Noun')],
#  [('전통', 'Noun'),
#   ('과', 'Josa'),
#   ('현', 'Modifier'),
#   ('대미', 'Noun'),
#   ('조화', 'Noun'),
#   ('를', 'Josa'),
#   ('이루는', 'Verb'),
#   ('곳', 'Noun'),
#   ('오랜', 'Modifier'),
#   ('만', 'Noun'),
#   ('에', 'Josa'),
#   ('방문', 'Noun'),
#   ('한', 'Josa'),
#   ('인사동', 'Noun'),
#   ('에서', 'Josa'),
#   ('전통', 'Noun'),
#   ('도', 'Josa'),
#   ('체험', 'Noun'),
#   ('하고', 'Josa'),
#   ('구경', 'Noun'),
#   ('도', 'Josa'),
#   ('실컷', 'Noun'),
#   ('했음', 'Verb'),
#   ('다소', 'Noun'),
#   ('아쉬웠다면', 'Adjective'),
#   ('주변', 'Noun'),
#   ('에', 'Josa'),
#   ('노점상', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('너무', 'Adverb'),
#   ('난잡하게', 'Adjective'),
#   ('산재', 'Noun'),
#   ('해서', 'Verb'),
#   ('지저분하다는', 'Adjective'),
#   ('느낌', 'Noun'),
#   ('이', 'Josa'),
#   ('들었고', 'Verb'),
#   ('기념품', 'Noun'),
#   ('판매', 'Noun'),
#   ('하는', 'Verb'),
#   ('곳', 'Noun'),
#   ('에서', 'Josa'),
#   ('많은', 'Adjective'),
#   ('기념품', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('중국산', 'Noun'),
#   ('이어서', 'Josa'),
#   ('너무', 'Adverb'),
#   ('아쉬였음', 'Adjective')],
#  [('인사동', 'Noun'),
#   ('은', 'Josa'),
#   ('보물', 'Noun'),
#   ('인사동', 'Noun'),
#   ('하면', 'Verb'),
#   ('전통', 'Noun'),
#   ('골목', 'Noun'),
#   ('아니겠습니까', 'Adjective'),
#   ('전', 'Modifier'),
#   ('통차', 'Noun'),
#   ('한정식', 'Noun'),
#   ('골목', 'Noun'),
#   ('등', 'Noun'),
#   ('으로', 'Josa'),
#   ('나누어져', 'Verb'),
#   ('즐기기', 'Verb'),
#   ('좋은', 'Adjective'),
#   ('장소', 'Noun'),
#   ('지', 'Josa'),
#   ('요', 'Modifier'),
#   ('외국인', 'Noun'),
#   ('들', 'Suffix'),
#   ('도', 'Josa'),
#   ('많이', 'Adverb'),
#   ('오고', 'Verb'),
#   ('지방', 'Noun'),
#   ('에서', 'Josa'),
#   ('서울', 'Noun'),
#   ('오면', 'Verb'),
#   ('꼭', 'Noun'),
#   ('보여주고', 'Verb'),
#   ('싶은', 'Verb'),
#   ('곳', 'Noun'),
#   ('이지', 'Noun'),
#   ('요', 'Josa')],
#  [('코로나', 'Noun'),
#   ('로', 'Josa'),
#   ('한산한', 'Adjective'),
#   ('거리', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('코로나', 'Noun'),
#   ('영향', 'Noun'),
#   ('으로', 'Josa'),
#   ('주말', 'Noun'),
#   ('인데', 'Josa'),
#   ('도', 'Noun'),
#   ('한산합니다', 'Adjective'),
#   ('주말', 'Noun'),
#   ('에는', 'Josa'),
#   ('차량', 'Noun'),
#   ('진입', 'Noun'),
#   ('금지', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('낮', 'Noun'),
#   ('에도', 'Josa'),
#   ('볼거리', 'Noun'),
#   ('가', 'Josa'),
#   ('있지만', 'Adjective'),
#   ('밤', 'Noun'),
#   ('에도', 'Josa'),
#   ('화려한', 'Adjective'),
#   ('곳', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('다양한', 'Adjective'),
#   ('제품', 'Noun'),
#   ('과', 'Josa'),
#   ('먹거리', 'Noun'),
#   ('액', 'Noun'),
#   ('티비', 'Noun'),
#   ('티', 'Noun'),
#   ('가', 'Josa'),
#   ('있습니다', 'Adjective'),
#   ('가족', 'Noun'),
#   ('연인', 'Noun'),
#   ('친구', 'Noun'),
#   ('들', 'Suffix'),
#   ('과', 'Josa'),
#   ('방문', 'Noun'),
#   ('해도', 'Verb'),
#   ('좋습니다', 'Adjective')],
#  [('좋아요', 'Adjective'),
#   ('프랜차이즈', 'Noun'),
#   ('화장품', 'Noun'),
#   ('가게', 'Noun'),
#   ('로', 'Josa'),
#   ('가득할거', 'Adjective'),
#   ('같았는데', 'Adjective'),
#   ('아직', 'Adverb'),
#   ('골목', 'Noun'),
#   ('골목', 'Noun'),
#   ('은', 'Josa'),
#   ('살아있네요', 'Verb'),
#   ('비싸서', 'Adjective'),
#   ('흠', 'Noun'),
#   ('이지만', 'Josa'),
#   ('예', 'Modifier'),
#   ('전', 'Modifier'),
#   ('인사동', 'Noun'),
#   ('으로', 'Josa'),
#   ('부활', 'Noun'),
#   ('하길', 'Verb'),
#   ('바', 'Noun'),
#   ('래', 'Josa'),
#   ('봅니다', 'Verb')],
#  [('인사동', 'Noun'),
#   ('안국역', 'Noun'),
#   ('이랑', 'Josa'),
#   ('가까워서', 'Adjective'),
#   ('구', 'Modifier'),
#   ('경도', 'Noun'),
#   ('하고', 'Josa'),
#   ('한', 'Determiner'),
#   ('옥', 'Noun'),
#   ('마을', 'Noun'),
#   ('이랑', 'Josa'),
#   ('도', 'Noun'),
#   ('가깝고', 'Adjective'),
#   ('교통', 'Noun'),
#   ('이', 'Josa'),
#   ('편리합니다', 'Adjective'),
#   ('걸어서', 'Verb'),
#   ('구경', 'Noun'),
#   ('할데가', 'Verb'),
#   ('많은것', 'Adjective'),
#   ('같아요', 'Adjective'),
#   ('주말', 'Noun'),
#   ('에는', 'Josa'),
#   ('많이', 'Adverb'),
#   ('혼잡하네요', 'Adjective')],
#  [('볼', 'Noun'),
#   ('것', 'Noun'),
#   ('없다', 'Adjective'),
#   ('먹고', 'Verb'),
#   ('배부르면', 'Adjective'),
#   ('쌈지', 'Noun'),
#   ('길이', 'Noun'),
#   ('나', 'Josa'),
#   ('한', 'Determiner'),
#   ('바퀴', 'Noun'),
#   ('돌', 'Noun'),
#   ('며', 'Josa'),
#   ('소화', 'Noun'),
#   ('시킨다', 'Verb'),
#   ('그리고', 'Conjunction'),
#   ('주변', 'Noun'),
#   ('에', 'Josa'),
#   ('뭐', 'Noun'),
#   ('먹잘', 'Verb'),
#   ('것', 'Noun'),
#   ('도', 'Josa'),
#   ('없는데다가', 'Adjective'),
#   ('있어도', 'Adjective'),
#   ('비싸기만', 'Adjective'),
#   ('할', 'Verb'),
#   ('뿐이', 'Adjective'),
#   ('다그', 'Noun'),
#   ('냥', 'Josa'),
#   ('중국', 'Noun'),
#   ('인들', 'Josa'),
#   ('상대로', 'Noun'),
#   ('장사', 'Noun'),
#   ('하세요', 'Verb')],
#  [('인사동', 'Noun'),
#   ('예전', 'Noun'),
#   ('에', 'Josa'),
#   ('비해', 'Verb'),
#   ('관광객', 'Noun'),
#   ('이나', 'Josa'),
#   ('현', 'Modifier'),
#   ('지인', 'Noun'),
#   ('이', 'Josa'),
#   ('믾', 'Noun'),
#   ('이', 'Josa'),
#   ('줄어든', 'Verb'),
#   ('느낌', 'Noun'),
#   ('이', 'Josa'),
#   ('있지만', 'Adjective'),
#   ('여전히', 'Adjective'),
#   ('정겹고', 'Adjective'),
#   ('재미있는', 'Adjective'),
#   ('인사동', 'Noun'),
#   ('주차', 'Noun'),
#   ('가', 'Josa'),
#   ('협소하', 'Noun'),
#   ('니', 'Josa'),
#   ('대중교통', 'Noun'),
#   ('추천', 'Noun'),
#   ('합니다', 'Verb')],
#  [('언제나', 'Adverb'),
#   ('외국', 'Noun'),
#   ('사람', 'Noun'),
#   ('이', 'Josa'),
#   ('많은', 'Adjective'),
#   ('제일', 'Noun'),
#   ('한국', 'Noun'),
#   ('같은', 'Adjective'),
#   ('곳', 'Noun'),
#   ('외국', 'Noun'),
#   ('사람', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('여행', 'Noun'),
#   ('오면', 'Verb'),
#   ('꼭', 'Noun'),
#   ('들르는', 'Verb'),
#   ('곳', 'Noun'),
#   ('이라죠', 'Verb'),
#   ('그만큼', 'Adverb'),
#   ('유명한', 'Adjective'),
#   ('곳도', 'Noun'),
#   ('많고', 'Adjective'),
#   ('한데', 'Eomi'),
#   ('좀', 'Noun'),
#   ('상업', 'Noun'),
#   ('화', 'Suffix'),
#   ('된', 'Verb'),
#   ('거리', 'Noun'),
#   ('라', 'Josa'),
#   ('막상', 'Noun'),
#   ('한국인', 'Noun'),
#   ('은', 'Josa'),
#   ('자주', 'Noun'),
#   ('안', 'VerbPrefix'),
#   ('가게', 'Verb'),
#   ('되더라구요', 'Verb'),
#   ('하지만', 'Conjunction'),
#   ('이', 'Noun'),
#   ('길', 'Noun'),
#   ('만을', 'Josa'),
#   ('목적', 'Noun'),
#   ('이', 'Josa'),
#   ('아니', 'Adjective'),
#   ('종로', 'Noun'),
#   ('전체', 'Noun'),
#   ('를', 'Josa'),
#   ('걸으면서', 'Verb'),
#   ('돌아다니', 'Verb'),
#   ('기', 'Noun'),
#   ('엔', 'Josa'),
#   ('재밌는', 'Adjective'),
#   ('곳', 'Noun'),
#   ('이', 'Suffix'),
#   ('예요', 'Josa'),
#   ('쓰윽', 'Noun'),
#   ('한번', 'Noun'),
#   ('들러', 'Verb'),
#   ('보세요', 'Verb')],
#  [('한번', 'Noun'),
#   ('쯤', 'Suffix'),
#   ('경험', 'Noun'),
#   ('해봐도', 'Verb'),
#   ('좋을', 'Adjective'),
#   ('곳', 'Noun'),
#   ('한국', 'Noun'),
#   ('적', 'Suffix'),
#   ('인', 'Josa'),
#   ('느낌', 'Noun'),
#   ('을', 'Josa'),
#   ('얻고', 'Verb'),
#   ('자하', 'Noun'),
#   ('는', 'Josa'),
#   ('외국인', 'Noun'),
#   ('들', 'Suffix'),
#   ('에게', 'Josa'),
#   ('한번', 'Noun'),
#   ('쯤', 'Noun'),
#   ('은', 'Josa'),
#   ('와', 'Verb'),
#   ('볼', 'Noun'),
#   ('만', 'Suffix'),
#   ('한', 'Josa'),
#   ('곳', 'Noun'),
#   ('이나', 'Josa'),
#   ('요새', 'Noun'),
#   ('너무', 'Adverb'),
#   ('상업', 'Noun'),
#   ('적', 'Suffix'),
#   ('인', 'Josa'),
#   ('가게', 'Noun'),
#   ('가', 'Josa'),
#   ('많아졌고', 'Verb'),
#   ('전통', 'Noun'),
#   ('적', 'Suffix'),
#   ('인', 'Josa'),
#   ('특색', 'Noun'),
#   ('은', 'Josa'),
#   ('사라지는', 'Verb'),
#   ('추세', 'Noun'),
#   ('다만', 'Noun'),
#   ('전통', 'Noun'),
#   ('적', 'Suffix'),
#   ('인', 'Josa'),
#   ('음식', 'Noun'),
#   ('과', 'Josa'),
#   ('식당', 'Noun'),
#   ('이', 'Josa'),
#   ('많으니', 'Adjective'),
#   ('식사', 'Noun'),
#   ('하러', 'Verb'),
#   ('와도', 'Josa'),
#   ('좋을', 'Adjective'),
#   ('거리', 'Noun')],
#  [('한국', 'Noun'),
#   ('의', 'Josa'),
#   ('대표', 'Noun'),
#   ('적', 'Suffix'),
#   ('인', 'Josa'),
#   ('조계종', 'Noun'),
#   ('사찰', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('한국', 'Noun'),
#   ('의', 'Josa'),
#   ('조계종', 'Noun'),
#   ('을', 'Josa'),
#   ('대표', 'Noun'),
#   ('하는', 'Verb'),
#   ('사찰', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('사찰', 'Noun'),
#   ('의', 'Josa'),
#   ('규모', 'Noun'),
#   ('는', 'Josa'),
#   ('작으나', 'Adjective'),
#   ('상징', 'Noun'),
#   ('성', 'Suffix'),
#   ('이', 'Josa'),
#   ('있습니다', 'Adjective'),
#   ('사대천왕', 'Noun'),
#   ('도', 'Josa'),
#   ('동판', 'Noun'),
#   ('으로', 'Josa'),
#   ('제작', 'Noun'),
#   ('되어서', 'Verb'),
#   ('톡특', 'Noun'),
#   ('합니다', 'Verb'),
#   ('사찰', 'Noun'),
#   ('내', 'Noun'),
#   ('에', 'Josa'),
#   ('아주', 'Noun'),
#   ('오래된', 'Adjective'),
#   ('고목', 'Noun'),
#   ('이', 'Josa'),
#   ('있어서', 'Adjective'),
#   ('한층', 'Noun'),
#   ('더신', 'Adjective'),
#   ('비감', 'Noun'),
#   ('을', 'Josa'),
#   ('느끼게', 'Verb'),
#   ('합니다', 'Verb'),
#   ('도심', 'Noun'),
#   ('에', 'Josa'),
#   ('위치', 'Noun'),
#   ('하고있어서', 'Verb'),
#   ('접근성', 'Noun'),
#   ('이', 'Josa'),
#   ('좋습니다', 'Adjective')],
#  [('서울', 'Noun'),
#   ('한', 'Determiner'),
#   ('복판', 'Noun'),
#   ('의', 'Josa'),
#   ('대형', 'Noun'),
#   ('사찰', 'Noun'),
#   ('과거', 'Noun'),
#   ('유명했던', 'Adjective'),
#   ('사이비', 'Noun'),
#   ('종교', 'Noun'),
#   ('보천교', 'Noun'),
#   ('의', 'Josa'),
#   ('본당', 'Noun'),
#   ('인', 'Josa'),
#   ('십', 'Modifier'),
#   ('일전', 'Noun'),
#   ('을', 'Josa'),
#   ('인수', 'Noun'),
#   ('해', 'Verb'),
#   ('개조', 'Noun'),
#   ('한', 'Josa'),
#   ('절', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('덕분', 'Noun'),
#   ('에', 'Josa'),
#   ('규모', 'Noun'),
#   ('하나', 'Noun'),
#   ('만큼은', 'Josa'),
#   ('국내', 'Noun'),
#   ('최대', 'Noun'),
#   ('목조', 'Noun'),
#   ('건물', 'Noun'),
#   ('중', 'Noun'),
#   ('하나', 'Noun'),
#   ('다만', 'Noun'),
#   ('사시', 'Noun'),
#   ('사철', 'Noun'),
#   ('연등', 'Noun'),
#   ('이', 'Josa'),
#   ('걸려있어', 'Verb'),
#   ('건물', 'Noun'),
#   ('전체', 'Noun'),
#   ('의', 'Josa'),
#   ('웅장', 'Noun'),
#   ('함', 'Noun'),
#   ('을', 'Josa'),
#   ('느끼', 'Verb'),
#   ('기', 'Noun'),
#   ('에는', 'Josa'),
#   ('늘', 'Noun'),
#   ('부족하다는', 'Adjective'),
#   ('생각', 'Noun'),
#   ('이', 'Josa'),
#   ('들어요', 'Verb')],
#  [('마음', 'Noun'),
#   ('이', 'Josa'),
#   ('복잡할', 'Adjective'),
#   ('때', 'Noun'),
#   ('는', 'Josa'),
#   ('방문', 'Noun'),
#   ('추천', 'Noun'),
#   ('종교', 'Noun'),
#   ('가', 'Josa'),
#   ('없어도', 'Adjective'),
#   ('가끔', 'Noun'),
#   ('마음', 'Noun'),
#   ('이', 'Josa'),
#   ('복잡할', 'Adjective'),
#   ('때', 'Noun'),
#   ('는', 'Josa'),
#   ('절', 'Noun'),
#   ('이나', 'Josa'),
#   ('교회', 'Noun'),
#   ('에', 'Josa'),
#   ('방문', 'Noun'),
#   ('할', 'Verb'),
#   ('것', 'Noun'),
#   ('을', 'Josa'),
#   ('추천', 'Noun'),
#   ('한다', 'Verb'),
#   ('조계사', 'Noun'),
#   ('는', 'Josa'),
#   ('다양한', 'Adjective'),
#   ('행사', 'Noun'),
#   ('도', 'Josa'),
#   ('많이하고', 'Adjective'),
#   ('차분하게', 'Adjective'),
#   ('마음', 'Noun'),
#   ('을', 'Josa'),
#   ('추', 'Noun'),
#   ('스릴', 'Noun'),
#   ('수', 'Noun'),
#   ('있는', 'Adjective'),
#   ('곳', 'Noun'),
#   ('이다', 'Josa'),
#   ('좋은', 'Adjective'),
#   ('마음', 'Noun'),
#   ('으로', 'Josa'),
#   ('소원', 'Noun'),
#   ('을', 'Josa'),
#   ('기원', 'Noun'),
#   ('하기에', 'Verb'),
#   ('좋다', 'Adjective'),
#   ('한', 'Determiner'),
#   ('시간', 'Noun'),
#   ('미만', 'Noun'),
#   ('으로', 'Josa'),
#   ('방문', 'Noun'),
#   ('하면', 'Verb'),
#   ('좋겠다', 'Adjective')],
#  [('항상', 'Noun'),
#   ('가을', 'Noun'),
#   ('에', 'Josa'),
#   ('이맘때', 'Adverb'),
#   ('항상', 'Noun'),
#   ('방문', 'Noun'),
#   ('합니다', 'Verb'),
#   ('국', 'Noun'),
#   ('하', 'Suffix'),
#   ('축제', 'Noun'),
#   ('하고', 'Josa'),
#   ('절', 'Noun'),
#   ('자체', 'Noun'),
#   ('도', 'Josa'),
#   ('너무', 'Adverb'),
#   ('이뿌고', 'Adjective'),
#   ('접근성', 'Noun'),
#   ('도', 'Josa'),
#   ('좋아서', 'Adjective'),
#   ('올해', 'Noun'),
#   ('는', 'Josa'),
#   ('국화', 'Noun'),
#   ('분재', 'Noun'),
#   ('가', 'Josa'),
#   ('있어', 'Adjective'),
#   ('아버지', 'Noun'),
#   ('가', 'Josa'),
#   ('흥미로워하셨어요', 'Adjective'),
#   ('매번', 'Noun'),
#   ('하', 'Suffix'),
#   ('지만', 'Josa'),
#   ('위치', 'Noun'),
#   ('도', 'Josa'),
#   ('바뀌고', 'Verb'),
#   ('전시', 'Noun'),
#   ('도', 'Josa'),
#   ('조금씩', 'Adverb'),
#   ('바', 'Noun'),
#   ('껴서', 'Verb'),
#   ('너무', 'Adverb'),
#   ('좋아요', 'Adjective'),
#   ('국화빵', 'Noun'),
#   ('도', 'Josa'),
#   ('팔고', 'Noun'),
#   ('좀', 'Noun'),
#   ('이색', 'Noun'),
#   ('적', 'Suffix'),
#   ('이지만', 'Josa'),
#   ('좋았어요', 'Adjective')],
#  [('서울', 'Noun'),
#   ('의', 'Josa'),
#   ('대표', 'Noun'),
#   ('불교', 'Noun'),
#   ('사찰', 'Noun'),
#   ('조계사', 'Noun'),
#   ('는', 'Josa'),
#   ('대', 'Modifier'),
#   ('한', 'Modifier'),
#   ('불교', 'Noun'),
#   ('조계종', 'Noun'),
#   ('의', 'Josa'),
#   ('총', 'Modifier'),
#   ('본', 'Modifier'),
#   ('산', 'Noun'),
#   ('으로', 'Josa'),
#   ('봉은사', 'Noun'),
#   ('길상사', 'Noun'),
#   ('와', 'Josa'),
#   ('함께', 'Adverb'),
#   ('서울', 'Noun'),
#   ('의', 'Josa'),
#   ('대표', 'Noun'),
#   ('불교', 'Noun'),
#   ('사찰', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('그', 'Noun'),
#   ('중요성', 'Noun'),
#   ('과는', 'Josa'),
#   ('달리', 'Noun'),
#   ('절의', 'Noun'),
#   ('규모', 'Noun'),
#   ('는', 'Josa'),
#   ('작은', 'Adjective'),
#   ('편이', 'Noun'),
#   ('지만', 'Josa'),
#   ('조계종', 'Noun'),
#   ('측', 'Noun'),
#   ('에서', 'Josa'),
#   ('장기', 'Noun'),
#   ('적', 'Suffix'),
#   ('으로', 'Josa'),
#   ('조계사', 'Noun'),
#   ('성역', 'Noun'),
#   ('화', 'Suffix'),
#   ('사업', 'Noun'),
#   ('을', 'Josa'),
#   ('진행', 'Noun'),
#   ('하고', 'Josa'),
#   ('있어', 'Adjective'),
#   ('점차', 'Noun'),
#   ('절의', 'Noun'),
#   ('규모', 'Noun'),
#   ('는', 'Josa'),
#   ('커질', 'Verb'),
#   ('것', 'Noun'),
#   ('으로', 'Josa'),
#   ('예상', 'Noun'),
#   ('됩니다', 'Verb'),
#   ('대웅전', 'Noun'),
#   ('내의', 'Noun'),
#   ('아미타여래', 'Noun'),
#   ('상', 'Suffix'),
#   ('석가여래', 'Noun'),
#   ('상', 'Suffix'),
#   ('약사여래', 'Noun'),
#   ('상', 'Suffix'),
#   ('앞', 'Noun'),
#   ('에', 'Josa'),
#   ('앉아', 'Verb'),
#   ('잠시', 'Noun'),
#   ('명상', 'Noun'),
#   ('을', 'Josa'),
#   ('해보시길', 'Verb'),
#   ('권합니다', 'Verb'),
#   ('대웅전', 'Noun'),
#   ('뒷', 'Modifier'),
#   ('편의', 'Noun'),
#   ('현대', 'Noun'),
#   ('적', 'Suffix'),
#   ('인', 'Josa'),
#   ('건물', 'Noun'),
#   ('지하', 'Noun'),
#   ('엔', 'Josa'),
#   ('불교', 'Noun'),
#   ('박물관', 'Noun'),
#   ('이', 'Josa'),
#   ('있으니', 'Adjective'),
#   ('꼭', 'Noun'),
#   ('방문', 'Noun'),
#   ('하시기', 'Verb'),
#   ('바랍니다', 'Verb')],
#  [('위치', 'Noun'),
#   ('가', 'Josa'),
#   ('좋음', 'Adjective'),
#   ('종로', 'Noun'),
#   ('갔다가', 'Verb'),
#   ('들르기', 'Verb'),
#   ('좋은', 'Adjective'),
#   ('곳', 'Noun'),
#   ('불상', 'Noun'),
#   ('이', 'Josa'),
#   ('생각', 'Noun'),
#   ('보다', 'Josa'),
#   ('크고', 'Verb'),
#   ('위엄', 'Noun'),
#   ('있어서', 'Adjective'),
#   ('놀랐다', 'Verb'),
#   ('다만', 'Noun'),
#   ('그', 'Noun'),
#   ('외', 'Noun'),
#   ('에', 'Josa'),
#   ('시설', 'Noun'),
#   ('이', 'Josa'),
#   ('많지', 'Adjective'),
#   ('않은', 'Verb'),
#   ('작은', 'Adjective'),
#   ('절', 'Noun'),
#   ('이다', 'Josa'),
#   ('한번', 'Noun'),
#   ('쯤', 'Suffix'),
#   ('가볼만', 'Verb'),
#   ('한', 'Determiner'),
#   ('곳', 'Noun')],
#  [('서울', 'Noun'),
#   ('에서', 'Josa'),
#   ('방문', 'Noun'),
#   ('하기', 'Verb'),
#   ('좋은', 'Adjective'),
#   ('절', 'Noun'),
#   ('중', 'Noun'),
#   ('하나', 'Noun'),
#   ('조계사', 'Noun'),
#   ('규모', 'Noun'),
#   ('가', 'Josa'),
#   ('매우', 'Noun'),
#   ('큰', 'Verb'),
#   ('절', 'Noun'),
#   ('중', 'Noun'),
#   ('하나', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('종로구', 'Noun'),
#   ('중심', 'Noun'),
#   ('가에', 'Verb'),
#   ('위치', 'Noun'),
#   ('한', 'Josa'),
#   ('절로', 'Noun'),
#   ('부처님', 'Noun'),
#   ('오신', 'Noun'),
#   ('날', 'Noun'),
#   ('혹은', 'Adverb'),
#   ('외국인', 'Noun'),
#   ('손님', 'Noun'),
#   ('이', 'Josa'),
#   ('왔을', 'Verb'),
#   ('때', 'Noun'),
#   ('방문', 'Noun'),
#   ('하기', 'Verb'),
#   ('좋습니다', 'Adjective')],
#  [('도심', 'Noun'),
#   ('에', 'Josa'),
#   ('있는', 'Adjective'),
#   ('절', 'Noun'),
#   ('인사동', 'Noun'),
#   ('바로', 'Noun'),
#   ('옆', 'Noun'),
#   ('에', 'Josa'),
#   ('있는', 'Adjective'),
#   ('조계종', 'Noun'),
#   ('대표', 'Noun'),
#   ('절', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('도심', 'Noun'),
#   ('에', 'Josa'),
#   ('한적하게', 'Adjective'),
#   ('불교', 'Noun'),
#   ('문화', 'Noun'),
#   ('를', 'Josa'),
#   ('느낄', 'Verb'),
#   ('수', 'Noun'),
#   ('있는', 'Adjective'),
#   ('곳', 'Noun'),
#   ('이라', 'Josa'),
#   ('가면', 'Noun'),
#   ('마음', 'Noun'),
#   ('이', 'Josa'),
#   ('편안해', 'Adjective'),
#   ('지고', 'Noun'),
#   ('고', 'Modifier'),
#   ('즈', 'Modifier'),
#   ('넉', 'Modifier'),
#   ('해', 'Noun'),
#   ('서', 'Josa'),
#   ('좋습니다', 'Adjective')],
#  [('조계사', 'Noun'),
#   ('종로', 'Noun'),
#   ('한가운데', 'Noun'),
#   ('에', 'Josa'),
#   ('위치', 'Noun'),
#   ('에서', 'Josa'),
#   ('접근성', 'Noun'),
#   ('이', 'Josa'),
#   ('가장', 'Noun'),
#   ('좋은', 'Adjective'),
#   ('곳', 'Noun'),
#   ('이', 'Josa'),
#   ('아닌가', 'Adjective'),
#   ('생각', 'Noun'),
#   ('된다', 'Verb'),
#   ('특히', 'Adverb'),
#   ('부처님', 'Noun'),
#   ('오', 'Modifier'),
#   ('신', 'Modifier'),
#   ('날', 'Noun'),
#   ('쯤', 'Suffix'),
#   ('에는', 'Josa'),
#   ('연등', 'Noun'),
#   ('과', 'Josa'),
#   ('꽃', 'Noun'),
#   ('이', 'Josa'),
#   ('예쁘게', 'Adjective'),
#   ('꾸며져', 'Verb'),
#   ('있어', 'Adjective'),
#   ('너무', 'Adverb'),
#   ('좋다', 'Adjective')],
#  [('반드시', 'Noun'),
#   ('들러야', 'Verb'),
#   ('하는', 'Verb'),
#   ('곳', 'Noun'),
#   ('은', 'Josa'),
#   ('아니', 'Adjective'),
#   ('짐', 'Noun'),
#   ('나', 'Josa'),
#   ('그래도', 'Adverb'),
#   ('들르면', 'Verb'),
#   ('좋을', 'Adjective'),
#   ('것', 'Noun'),
#   ('같습니다', 'Adjective'),
#   ('반드시', 'Noun'),
#   ('들러야', 'Verb'),
#   ('하는', 'Verb'),
#   ('곳', 'Noun'),
#   ('은', 'Josa'),
#   ('아니', 'Adjective'),
#   ('짐', 'Noun'),
#   ('나', 'Josa'),
#   ('그래도', 'Adverb'),
#   ('들르면', 'Verb'),
#   ('좋을', 'Adjective'),
#   ('것', 'Noun'),
#   ('같습니다', 'Adjective'),
#   ('볼', 'Noun'),
#   ('거리', 'Noun'),
#   ('많은', 'Adjective'),
#   ('종로', 'Noun'),
#   ('에서', 'Josa'),
#   ('조계사', 'Noun'),
#   ('에', 'Josa'),
#   ('들르면', 'Verb'),
#   ('참', 'Verb'),
#   ('좋을', 'Adjective'),
#   ('것', 'Noun'),
#   ('같단', 'Adjective'),
#   ('생각', 'Noun'),
#   ('이', 'Josa'),
#   ('듭니', 'Noun'),
#   ('다', 'Josa')],
#  [('청와대', 'Noun'),
#   ('관람', 'Noun'),
#   ('투어', 'Noun'),
#   ('개월', 'Noun'),
#   ('전', 'Noun'),
#   ('에', 'Josa'),
#   ('예약', 'Noun'),
#   ('하고', 'Josa'),
#   ('주말', 'Noun'),
#   ('에', 'Josa'),
#   ('가족', 'Noun'),
#   ('들', 'Suffix'),
#   ('과', 'Josa'),
#   ('함께', 'Adverb'),
#   ('다녀왔습니다', 'Verb'),
#   ('경복궁', 'Noun'),
#   ('은', 'Josa'),
#   ('여러', 'Modifier'),
#   ('번', 'Noun'),
#   ('갔는데', 'Verb'),
#   ('항상', 'Noun'),
#   ('멀리', 'Noun'),
#   ('서', 'Josa'),
#   ('보던', 'Verb'),
#   ('청와대', 'Noun'),
#   ('를', 'Josa'),
#   ('들어가', 'Verb'),
#   ('보니', 'Verb'),
#   ('상징', 'Noun'),
#   ('적', 'Suffix'),
#   ('인', 'Josa'),
#   ('곳', 'Noun'),
#   ('이라', 'Josa'),
#   ('경비', 'Noun'),
#   ('가', 'Josa'),
#   ('삼엄하긴', 'Adjective'),
#   ('하지만', 'Conjunction'),
#   ('고', 'Modifier'),
#   ('즈', 'Modifier'),
#   ('넉', 'Noun'),
#   ('하고', 'Josa'),
#   ('좋았습니다', 'Adjective'),
#   ('투어', 'Noun'),
#   ('중', 'Suffix'),
#   ('에는', 'Josa'),
#   ('화장실', 'Noun'),
#   ('이', 'Josa'),
#   ('없으니', 'Adjective'),
#   ('청와대', 'Noun'),
#   ('관람차', 'Noun'),
#   ('에서', 'Josa'),
#   ('내려', 'Verb'),
#   ('보안', 'Noun'),
#   ('검색', 'Noun'),
#   ('하', 'Suffix'),
#   ('기전', 'Noun'),
#   ('화장실', 'Noun'),
#   ('을', 'Josa'),
#   ('들러주는게', 'Verb'),
#   ('좋을', 'Adjective'),
#   ('것', 'Noun'),
#   ('같습니다', 'Adjective'),
#   ('기념품', 'Noun'),
#   ('으로', 'Josa'),
#   ('성인', 'Noun'),
#   ('에게는', 'Josa'),
#   ('머그컵', 'Noun'),
#   ('아이', 'Noun'),
#   ('들', 'Suffix'),
#   ('에게는', 'Josa'),
#   ('버스', 'Noun'),
#   ('카드', 'Noun'),
#   ('를', 'Josa'),
#   ('넣을수', 'Verb'),
#   ('있는', 'Adjective'),
#   ('목걸이', 'Noun'),
#   ('지갑', 'Noun'),
#   ('을', 'Josa'),
#   ('주었습니다', 'Verb'),
#   ('산책', 'Noun'),
#   ('하는', 'Verb'),
#   ('겸', 'Noun'),
#   ('저', 'Noun'),
#   ('는', 'Josa'),
#   ('너무', 'Adverb'),
#   ('만족했으나', 'Adjective'),
#   ('햇빛', 'Noun'),
#   ('을', 'Josa'),
#   ('피', 'Noun'),
#   ('할', 'Verb'),
#   ('곳', 'Noun'),
#   ('이', 'Josa'),
#   ('따로', 'Adverb'),
#   ('없으니', 'Adjective'),
#   ('모자', 'Noun'),
#   ('나', 'Josa'),
#   ('생수', 'Noun'),
#   ('이', 'Determiner'),
#   ('온', 'Modifier'),
#   ('음료', 'Noun'),
#   ('정도', 'Noun'),
#   ('는', 'Josa'),
#   ('챙겨', 'Verb'),
#   ('가세', 'Noun'),
#   ('요', 'Josa')],
#  [('청와대', 'Noun'),
#   ('내부', 'Noun'),
#   ('관람', 'Noun'),
#   ('을', 'Josa'),
#   ('위', 'Noun'),
#   ('해서는', 'Verb'),
#   ('사전예약', 'Noun'),
#   ('이', 'Josa'),
#   ('필요합니다', 'Adjective'),
#   ('예약', 'Noun'),
#   ('을', 'Josa'),
#   ('하지', 'Verb'),
#   ('않았을', 'Verb'),
#   ('경우', 'Noun'),
#   ('외부', 'Noun'),
#   ('전경', 'Noun'),
#   ('을', 'Josa'),
#   ('보면서', 'Verb'),
#   ('기념', 'Noun'),
#   ('촬영', 'Noun'),
#   ('하기', 'Verb'),
#   ('좋습니다', 'Adjective')],
#  [('청와대', 'Noun'),
#   ('대한민국', 'Noun'),
#   ('대통령', 'Noun'),
#   ('의', 'Josa'),
#   ('집무실', 'Noun'),
#   ('과', 'Josa'),
#   ('관저', 'Noun'),
#   ('가', 'Josa'),
#   ('있죠', 'Adjective'),
#   ('청와대', 'Noun'),
#   ('앞길', 'Noun'),
#   ('이', 'Josa'),
#   ('최근', 'Noun'),
#   ('에', 'Josa'),
#   ('개방', 'Noun'),
#   ('되서', 'Verb'),
#   ('좀', 'Noun'),
#   ('더', 'Noun'),
#   ('가까워진', 'Verb'),
#   ('느낌', 'Noun'),
#   ('이에요', 'Josa')],
#  [('청와대', 'Noun'),
#   ('는', 'Josa'),
#   ('예', 'Modifier'),
#   ('약제', 'Noun'),
#   ('내부', 'Noun'),
#   ('로는', 'Josa'),
#   ('예약', 'Noun'),
#   ('하지', 'Verb'),
#   ('못', 'VerbPrefix'),
#   ('해서', 'Verb'),
#   ('들어가지', 'Verb'),
#   ('못', 'VerbPrefix'),
#   ('했지만', 'Verb'),
#   ('외곽', 'Noun'),
#   ('을', 'Josa'),
#   ('따라', 'Verb'),
#   ('돌담', 'Noun'),
#   ('길', 'Noun'),
#   ('을', 'Josa'),
#   ('걷는건', 'Verb'),
#   ('너무', 'Adverb'),
#   ('멋져요', 'Adjective'),
#   ('특히', 'Adverb'),
#   ('가을', 'Noun'),
#   ('에', 'Josa'),
#   ('낙엽', 'Noun'),
#   ('이', 'Josa'),
#   ('질때', 'Noun'),
#   ('더', 'Noun'),
#   ('멋', 'Noun'),
#   ('스러워', 'Adjective'),
#   ('욘', 'Noun')],
#  [('청와대', 'Noun'),
#   ('청와대', 'Noun'),
#   ('관람', 'Noun'),
#   ('은', 'Josa'),
#   ('예약', 'Noun'),
#   ('이', 'Josa'),
#   ('필요하나', 'Adjective'),
#   ('경복궁', 'Noun'),
#   ('담', 'Noun'),
#   ('을', 'Josa'),
#   ('따라', 'Verb'),
#   ('청와대', 'Noun'),
#   ('앞', 'Noun'),
#   ('을', 'Josa'),
#   ('걸어', 'Verb'),
#   ('봐도', 'Verb'),
#   ('좋습니다', 'Adjective'),
#   ('아름다운', 'Adjective'),
#   ('길', 'Noun'),
#   ('입니다', 'Adjective')],
#  [('청와대', 'Noun'),
#   ('공원', 'Noun'),
#   ('개방', 'Noun'),
#   ('으로', 'Josa'),
#   ('청와대', 'Noun'),
#   ('앞', 'Noun'),
#   ('공원', 'Noun'),
#   ('둘러보기', 'Noun'),
#   ('추천', 'Noun'),
#   ('청와대', 'Noun'),
#   ('견학', 'Noun'),
#   ('은', 'Josa'),
#   ('예약', 'Noun'),
#   ('제로', 'Noun'),
#   ('운영', 'Noun'),
#   ('하지만', 'Verb'),
#   ('올해', 'Noun'),
#   ('부터', 'Josa'),
#   ('청와대', 'Noun'),
#   ('공원', 'Noun'),
#   ('인근', 'Noun'),
#   ('검문', 'Noun'),
#   ('없이', 'Adverb'),
#   ('자유롭게', 'Adjective'),
#   ('산책', 'Noun'),
#   ('할', 'Verb'),
#   ('수', 'Noun'),
#   ('있습니다', 'Adjective'),
#   ('편안하게', 'Adjective'),
#   ('청와대', 'Noun'),
#   ('공원', 'Noun'),
#   ('산책', 'Noun'),
#   ('하고', 'Josa'),
#   ('청와대', 'Noun'),
#   ('바라보며', 'Verb'),
#   ('삼청동', 'Noun'),
#   ('까지', 'Josa'),
#   ('천천히', 'Adverb'),
#   ('걸었습니다', 'Verb')],
#  [('가볼만', 'Verb'),
#   ('한', 'Determiner'),
#   ('가치', 'Noun'),
#   ('가', 'Josa'),
#   ('있네여', 'Adjective'),
#   ('예약', 'Noun'),
#   ('하고', 'Josa'),
#   ('가셔야', 'Verb'),
#   ('해', 'Noun'),
#   ('요', 'Josa'),
#   ('경비', 'Noun'),
#   ('엄청', 'Adverb'),
#   ('삼엄하고', 'Adjective'),
#   ('사진', 'Noun'),
#   ('도', 'Josa'),
#   ('찍을수', 'Verb'),
#   ('있는', 'Adjective'),
#   ('곳', 'Noun'),
#   ('정해', 'Noun'),
#   ('쟈', 'Noun'),
#   ('있는데', 'Adjective'),
#   ('그럼에도', 'Adjective'),
#   ('불구', 'Noun'),
#   ('하고', 'Josa'),
#   ('유익함단', 'Adjective'),
#   ('볕', 'Noun'),
#   ('피', 'Noun'),
#   ('할데가', 'Verb'),
#   ('없어서', 'Adjective'),
#   ('모자', 'Noun'),
#   ('필수', 'Noun'),
#   ('친절하고', 'Adjective'),
#   ('아이', 'Noun'),
#   ('들', 'Suffix'),
#   ('교육', 'Noun'),
#   ('에도', 'Josa'),
#   ('좋아요', 'Adjective')],
#  [('서울', 'Noun'),
#   ('의', 'Josa'),
#   ('중심', 'Noun'),
#   ('물론', 'Adverb'),
#   ('통치', 'Noun'),
#   ('의', 'Josa'),
#   ('핵심', 'Noun'),
#   ('장소', 'Noun'),
#   ('이기도', 'Josa'),
#   ('하나', 'Noun'),
#   ('뒤', 'Noun'),
#   ('에', 'Josa'),
#   ('병풍', 'Noun'),
#   ('처럼', 'Josa'),
#   ('두른', 'Verb'),
#   ('산들', 'Noun'),
#   ('과', 'Josa'),
#   ('앞', 'Noun'),
#   ('광화문', 'Noun'),
#   ('광장', 'Noun'),
#   ('양쪽', 'Noun'),
#   ('북촌', 'Noun'),
#   ('과', 'Josa'),
#   ('서', 'Modifier'),
#   ('촌', 'Noun'),
#   ('사이', 'Noun'),
#   ('에', 'Josa'),
#   ('청와대', 'Noun'),
#   ('가', 'Josa'),
#   ('있다', 'Adjective'),
#   ('위치', 'Noun'),
#   ('적', 'Suffix'),
#   ('으로도', 'Josa'),
#   ('서울', 'Noun'),
#   ('의', 'Josa'),
#   ('요지', 'Noun'),
#   ('이자', 'Noun'),
#   ('중심', 'Noun'),
#   ('에', 'Josa'),
#   ('청와대', 'Noun'),
#   ('가', 'Josa'),
#   ('있다', 'Adjective'),
#   ('차가', 'Adjective'),
#   ('지나가야하는', 'Verb'),
#   ('루트', 'Noun'),
#   ('라', 'Josa'),
#   ('검문', 'Noun'),
#   ('을', 'Josa'),
#   ('하고', 'Verb'),
#   ('지나갔는데', 'Verb'),
#   ('의경', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('친절했고', 'Adjective'),
#   ('비록', 'Noun'),
#   ('지나치기만', 'Verb'),
#   ('했지만', 'Verb'),
#   ('요새', 'Noun'),
#   ('같은', 'Adjective'),
#   ('시국', 'Noun'),
#   ('에', 'Josa'),
#   ('만', 'Modifier'),
#   ('감', 'Noun'),
#   ('이', 'Josa'),
#   ('교차', 'Noun'),
#   ('했다', 'Verb')],
#  [('청와대', 'Noun'),
#   ('관람', 'Noun'),
#   ('저', 'Noun'),
#   ('는', 'Josa'),
#   ('청와대', 'Noun'),
#   ('가', 'Josa'),
#   ('너무', 'Adverb'),
#   ('궁금하여', 'Adjective'),
#   ('미리', 'Noun'),
#   ('예약', 'Noun'),
#   ('을', 'Josa'),
#   ('해서', 'Verb'),
#   ('입장', 'Noun'),
#   ('하였습니다', 'Verb'),
#   ('물론', 'Adverb'),
#   ('개월전', 'Noun'),
#   ('에', 'Josa'),
#   ('예약', 'Noun'),
#   ('제로', 'Noun'),
#   ('운영', 'Noun'),
#   ('이', 'Josa'),
#   ('되는', 'Verb'),
#   ('곳', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('관람', 'Noun'),
#   ('료', 'Noun'),
#   ('는', 'Josa'),
#   ('없어요', 'Adjective'),
#   ('무료', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('대신', 'Noun'),
#   ('개인', 'Noun'),
#   ('일', 'Modifier'),
#   ('경우', 'Noun'),
#   ('명', 'Noun'),
#   ('이하', 'Noun'),
#   ('로', 'Josa'),
#   ('단체', 'Noun'),
#   ('일', 'Modifier'),
#   ('경우', 'Noun'),
#   ('명', 'Noun'),
#   ('이하', 'Noun'),
#   ('로', 'Josa'),
#   ('신청', 'Noun'),
#   ('이', 'Josa'),
#   ('가능합니다', 'Adjective'),
#   ('관람', 'Noun'),
#   ('은', 'Josa'),
#   ('매주', 'Adverb'),
#   ('화요일', 'Noun'),
#   ('금요일', 'Noun'),
#   ('토요일', 'Noun'),
#   ('은', 'Josa'),
#   ('둘째', 'Noun'),
#   ('넷내주', 'Noun'),
#   ('에', 'Josa'),
#   ('가능합니다', 'Adjective'),
#   ('관람', 'Noun'),
#   ('시간', 'Noun'),
#   ('은', 'Josa'),
#   ('오전', 'Noun'),
#   ('시', 'Noun'),
#   ('시', 'Noun'),
#   ('오후', 'Noun'),
#   ('시', 'Noun'),
#   ('시로', 'Noun'),
#   ('하루', 'Noun'),
#   ('에', 'Josa'),
#   ('번', 'Noun'),
#   ('을', 'Josa'),
#   ('운영', 'Noun'),
#   ('중', 'Suffix'),
#   ('입니다', 'Adjective'),
#   ('총', 'Modifier'),
#   ('관람', 'Noun'),
#   ('은', 'Josa'),
#   ('한', 'Determiner'),
#   ('시반', 'Noun'),
#   ('이', 'Josa'),
#   ('걸립니다', 'Verb'),
#   ('관람', 'Noun'),
#   ('코스', 'Noun'),
#   ('는', 'Josa'),
#   ('만남', 'Noun'),
#   ('의', 'Josa'),
#   ('장소', 'Noun'),
#   ('홍보', 'Noun'),
#   ('관', 'Noun'),
#   ('녹지', 'Noun'),
#   ('원', 'Suffix'),
#   ('구', 'Noun'),
#   ('본관', 'Noun'),
#   ('터', 'Noun'),
#   ('소', 'Modifier'),
#   ('정원', 'Noun'),
#   ('본관', 'Noun'),
#   ('영빈', 'Noun'),
#   ('관', 'Noun'),
#   ('칠궁', 'Noun'),
#   ('무궁화', 'Noun'),
#   ('동산', 'Noun'),
#   ('청와대', 'Noun'),
#   ('사랑', 'Noun'),
#   ('채', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('대중교통', 'Noun'),
#   ('을', 'Josa'),
#   ('이용', 'Noun'),
#   ('하시는', 'Verb'),
#   ('분', 'Noun'),
#   ('들', 'Suffix'),
#   ('은', 'Josa'),
#   ('지하철', 'Noun'),
#   ('호선', 'Noun'),
#   ('경복궁역', 'Noun'),
#   ('번', 'Noun'),
#   ('출구', 'Noun'),
#   ('를', 'Josa'),
#   ('이용', 'Noun'),
#   ('하여', 'Verb'),
#   ('주셔야', 'Verb'),
#   ('합니다', 'Verb')],
#  [('한번', 'Noun'),
#   ('은', 'Josa'),
#   ('가봐야', 'Verb'),
#   ('할', 'Verb'),
#   ('곳', 'Noun'),
#   ('대통령', 'Noun'),
#   ('이', 'Josa'),
#   ('계신', 'Adjective'),
#   ('곳', 'Noun'),
#   ('이라', 'Josa'),
#   ('경비', 'Noun'),
#   ('가', 'Josa'),
#   ('삼엄하네요', 'Adjective'),
#   ('경복궁', 'Noun'),
#   ('뒤쪽', 'Noun'),
#   ('에', 'Josa'),
#   ('있어', 'Adjective'),
#   ('아이', 'Noun'),
#   ('들', 'Suffix'),
#   ('교육', 'Noun'),
#   ('면', 'Noun'),
#   ('에서도', 'Josa'),
#   ('고궁', 'Noun'),
#   ('갈', 'Verb'),
#   ('때', 'Noun'),
#   ('걸어가', 'Verb'),
#   ('보면', 'Verb'),
#   ('좋아요', 'Adjective'),
#   ('청와대', 'Noun'),
#   ('투어', 'Noun'),
#   ('도', 'Josa'),
#   ('있다하니', 'Adjective'),
#   ('내부', 'Noun'),
#   ('도', 'Josa'),
#   ('가보고', 'Verb'),
#   ('싶네요', 'Verb')],
#  [('보신각', 'Noun'),
#   ('지나가면서', 'Verb'),
#   ('보신각', 'Noun'),
#   ('지나가면서', 'Verb'),
#   ('한', 'Determiner'),
#   ('번식', 'Noun'),
#   ('사진', 'Noun'),
#   ('도', 'Josa'),
#   ('직고', 'Noun'),
#   ('너무', 'Adverb'),
#   ('좋아', 'Adjective'),
#   ('하는대', 'Verb'),
#   ('요즈음', 'Noun'),
#   ('은', 'Josa'),
#   ('한', 'Determiner'),
#   ('번식', 'Noun'),
#   ('지나가다', 'Verb'),
#   ('보면', 'Verb'),
#   ('대모', 'Noun'),
#   ('만', 'Josa'),
#   ('하고있어서', 'Verb'),
#   ('참', 'Verb'),
#   ('그렇다', 'Adjective'),
#   ('문화재', 'Noun'),
#   ('만큼', 'Noun'),
#   ('이나', 'Noun'),
#   ('성', 'Modifier'),
#   ('수', 'Modifier'),
#   ('러워', 'Noun'),
#   ('야하는대', 'Adjective'),
#   ('ㅠㅠㅠ', 'KoreanParticle')],
#  [('새해', 'Noun'),
#   ('를', 'Josa'),
#   ('맞이', 'Noun'),
#   ('하여', 'Verb'),
#   ('울리는', 'Verb'),
#   ('종소리', 'Noun'),
#   ('티비', 'Noun'),
#   ('를', 'Josa'),
#   ('보면', 'Verb'),
#   ('항상', 'Noun'),
#   ('커플', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('모', 'Noun'),
#   ('여서', 'Josa'),
#   ('키스', 'Noun'),
#   ('하는', 'Verb'),
#   ('장소', 'Noun'),
#   ('로', 'Josa'),
#   ('기억', 'Noun'),
#   ('이', 'Josa'),
#   ('많이', 'Adverb'),
#   ('남네요', 'Verb'),
#   ('평소', 'Noun'),
#   ('에', 'Josa'),
#   ('가면', 'Noun'),
#   ('가까이', 'Noun'),
#   ('접근', 'Noun'),
#   ('은', 'Josa'),
#   ('하지못하나', 'Verb'),
#   ('공원', 'Noun'),
#   ('으로서', 'Josa'),
#   ('인상', 'Noun'),
#   ('깊습니다', 'Adjective')],
#  [('좋은', 'Adjective'),
#   ('곳', 'Noun'),
#   ('매년', 'Noun'),
#   ('말일', 'Noun'),
#   ('에', 'Josa'),
#   ('이', 'Determiner'),
#   ('곳', 'Noun'),
#   ('을', 'Josa'),
#   ('방문', 'Noun'),
#   ('하면', 'Verb'),
#   ('에', 'Josa'),
#   ('나올지도', 'Verb'),
#   ('모른다', 'Verb'),
#   ('평소', 'Noun'),
#   ('에는', 'Josa'),
#   ('별일', 'Noun'),
#   ('없이', 'Adverb'),
#   ('조용한', 'Adjective'),
#   ('곳', 'Noun'),
#   ('도심', 'Noun'),
#   ('한', 'Verb'),
#   ('가운데', 'Noun'),
#   ('이런', 'Adjective'),
#   ('종이', 'Noun'),
#   ('있다는것이', 'Adjective'),
#   ('조금', 'Noun'),
#   ('신기', 'Noun')],
#  [('보신각', 'Noun'),
#   ('타종', 'Noun'),
#   ('의', 'Josa'),
#   ('주인공', 'Noun'),
#   ('종각역', 'Noun'),
#   ('지나갈', 'Verb'),
#   ('때', 'Noun'),
#   ('아무', 'Modifier'),
#   ('생각', 'Noun'),
#   ('없이', 'Adverb'),
#   ('지나곤', 'Verb'),
#   ('했는데', 'Verb'),
#   ('여기', 'Noun'),
#   ('가', 'Josa'),
#   ('바로', 'Noun'),
#   ('보신각', 'Noun'),
#   ('이더라고요', 'Verb'),
#   ('ㅋㅋㅋ', 'KoreanParticle'),
#   ('보신각', 'Noun'),
#   ('타종', 'Noun'),
#   ('항상', 'Noun'),
#   ('그', 'Determiner'),
#   ('맘때', 'Noun'),
#   ('면', 'Josa'),
#   ('정말', 'Noun'),
#   ('사람', 'Noun'),
#   ('이', 'Josa'),
#   ('엄청나게', 'Adjective'),
#   ('몰려서', 'Verb'),
#   ('그거', 'Noun'),
#   ('한번', 'Noun'),
#   ('듣겠다고', 'Verb'),
#   ('말', 'Noun'),
#   ('이', 'Suffix'),
#   ('죠', 'Josa'),
#   ('집', 'Noun'),
#   ('에서', 'Josa'),
#   ('티비', 'Noun'),
#   ('를', 'Josa'),
#   ('보는', 'Verb'),
#   ('대도', 'Noun'),
#   ('사람', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('무지하게', 'Adjective'),
#   ('많아', 'Adjective'),
#   ('보이던데', 'Verb'),
#   ('직접', 'Noun'),
#   ('온', 'Noun'),
#   ('사람', 'Noun'),
#   ('은', 'Josa'),
#   ('오죽하겠습니까', 'Adjective'),
#   ('멀리', 'Noun'),
#   ('서', 'Josa'),
#   ('볼수', 'Verb'),
#   ('밖에', 'Josa'),
#   ('없어서', 'Adjective'),
#   ('아쉽긴', 'Adjective'),
#   ('하지만', 'Conjunction'),
#   ('그래도', 'Adverb'),
#   ('문화', 'Noun'),
#   ('의', 'Josa'),
#   ('유산', 'Noun'),
#   ('안내', 'Noun'),
#   ('표지', 'Noun'),
#   ('만', 'Josa'),
#   ('보고', 'Noun'),
#   ('갈', 'Verb'),
#   ('때름', 'Noun'),
#   ('이네', 'Josa'),
#   ('요', 'Noun')],
#  [('방문', 'Noun'),
#   ('기', 'Noun'),
#   ('연말', 'Noun'),
#   ('연', 'Modifier'),
#   ('시', 'Noun'),
#   ('에', 'Josa'),
#   ('서울', 'Noun'),
#   ('에서', 'Josa'),
#   ('타종', 'Noun'),
#   ('행사', 'Noun'),
#   ('를', 'Josa'),
#   ('하는', 'Verb'),
#   ('곳', 'Noun'),
#   ('으로', 'Josa'),
#   ('유명한', 'Adjective'),
#   ('이', 'Determiner'),
#   ('곳', 'Noun'),
#   ('은', 'Josa'),
#   ('서울', 'Noun'),
#   ('시민', 'Noun'),
#   ('모두', 'Noun'),
#   ('가', 'Josa'),
#   ('다', 'Adverb'),
#   ('아는', 'Verb'),
#   ('랜드마크', 'Noun'),
#   ('로', 'Josa'),
#   ('종로', 'Noun'),
#   ('가', 'Josa'),
#   ('도심', 'Noun'),
#   ('한', 'Determiner'),
#   ('복판', 'Noun'),
#   ('누각', 'Noun'),
#   ('에', 'Josa'),
#   ('종이', 'Noun'),
#   ('있어', 'Adjective'),
#   ('새삼', 'Noun'),
#   ('우리', 'Noun'),
#   ('민족', 'Noun'),
#   ('의', 'Josa'),
#   ('자긍심', 'Noun'),
#   ('을', 'Josa'),
#   ('일', 'Noun'),
#   ('깨우는', 'Verb'),
#   ('곳', 'Noun'),
#   ('입니다', 'Adjective')],
#  [('정오', 'Noun'),
#   ('의', 'Josa'),
#   ('이벤트', 'Noun'),
#   ('점심', 'Noun'),
#   ('시', 'Noun'),
#   ('전', 'Noun'),
#   ('에', 'Josa'),
#   ('가면', 'Noun'),
#   ('한복', 'Noun'),
#   ('을', 'Josa'),
#   ('입고', 'Verb'),
#   ('종', 'Noun'),
#   ('을', 'Josa'),
#   ('칠', 'Noun'),
#   ('수', 'Noun'),
#   ('있는', 'Adjective'),
#   ('이벤트', 'Noun'),
#   ('가', 'Josa'),
#   ('있습니다', 'Adjective'),
#   ('시', 'Noun'),
#   ('분', 'Noun'),
#   ('정도', 'Noun'),
#   ('에', 'Josa'),
#   ('가서', 'Verb'),
#   ('사진', 'Noun'),
#   ('찍고시에', 'Verb'),
#   ('종', 'Noun'),
#   ('을', 'Josa'),
#   ('치는데', 'Verb'),
#   ('정말', 'Noun'),
#   ('좋았어요', 'Adjective'),
#   ('내', 'Determiner'),
#   ('국', 'Noun'),
#   ('인', 'Suffix'),
#   ('은', 'Josa'),
#   ('인터넷', 'Noun'),
#   ('에서', 'Josa'),
#   ('미리', 'Noun'),
#   ('신청', 'Noun'),
#   ('을', 'Josa'),
#   ('해야하지만', 'Verb'),
#   ('외국', 'Noun'),
#   ('은', 'Josa'),
#   ('은', 'Noun'),
#   ('즉석', 'Noun'),
#   ('에서', 'Josa'),
#   ('가능합니다', 'Adjective')],
#  [('좋아요', 'Adjective'),
#   ('도심', 'Noun'),
#   ('속', 'Noun'),
#   ('의', 'Josa'),
#   ('한', 'Determiner'),
#   ('옥', 'Noun'),
#   ('무더운', 'Adjective'),
#   ('여름', 'Noun'),
#   ('에', 'Josa'),
#   ('방문', 'Noun'),
#   ('하면', 'Verb'),
#   ('낭패', 'Noun'),
#   ('봅니다', 'Verb'),
#   ('그늘', 'Noun'),
#   ('에', 'Josa'),
#   ('쉴만', 'Verb'),
#   ('한', 'Determiner'),
#   ('곳도', 'Noun'),
#   ('없습니다', 'Adjective'),
#   ('동선', 'Noun'),
#   ('은', 'Josa'),
#   ('짧아서', 'Adjective'),
#   ('짧은', 'Adjective'),
#   ('시간', 'Noun'),
#   ('관람', 'Noun'),
#   ('가능하며', 'Adjective'),
#   ('보신각종', 'Noun'),
#   ('앞', 'Noun'),
#   ('에까지는', 'Josa'),
#   ('못', 'VerbPrefix'),
#   ('가게', 'Verb'),
#   ('작은', 'Adjective'),
#   ('울타리', 'Noun'),
#   ('쳐져있습니다', 'Verb'),
#   ('도심', 'Noun'),
#   ('이라', 'Josa'),
#   ('자차', 'Noun'),
#   ('보다는', 'Josa'),
#   ('대중교통', 'Noun'),
#   ('이용', 'Noun'),
#   ('하시면되', 'Verb'),
#   ('고요', 'Noun'),
#   ('굳이', 'Noun'),
#   ('자차', 'Noun'),
#   ('를', 'Josa'),
#   ('이용', 'Noun'),
# ...
#   ('공원', 'Noun'),
#   ('으로', 'Josa'),
#   ('넓은', 'Adjective'),
#   ('잔디밭', 'Noun'),
#   ('이', 'Josa'),
#   ('펼쳐져있어', 'Verb'),
#   ('아이', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('놀기에도', 'Verb'),
#   ('좋고', 'Adjective'),
#   ('가족', 'Noun'),
#   ('단', 'Modifier'),
#   ('위로', 'Noun'),
#   ('산책', 'Noun'),
#   ('하기에', 'Verb'),
#   ('좋은', 'Adjective'),
#   ('곳', 'Noun'),
#   ('이다', 'Josa')],
#  [('사계절', 'Noun'),
#   ('내내', 'Noun'),
#   ('아름다운', 'Adjective'),
#   ('곳', 'Noun'),
#   ('여름', 'Noun'),
#   ('에는', 'Josa'),
#   ('아름다운', 'Adjective'),
#   ('꽃', 'Noun'),
#   ('과', 'Josa'),
#   ('푸르름', 'Noun'),
#   ('으로', 'Josa'),
#   ('또', 'Noun'),
#   ('겨울', 'Noun'),
#   ('에는', 'Josa'),
#   ('밤', 'Noun'),
#   ('에', 'Josa'),
#   ('펼쳐지는', 'Verb'),
#   ('아름다운', 'Adjective'),
#   ('야경', 'Noun'),
#   ('으로', 'Josa'),
#   ('인해', 'Adjective'),
#   ('사계절', 'Noun'),
#   ('내내', 'Noun'),
#   ('아름다운', 'Adjective'),
#   ('곳', 'Noun'),
#   ('으로', 'Josa'),
#   ('방문', 'Noun'),
#   ('을', 'Josa'),
#   ('추천', 'Noun'),
#   ('함', 'Noun')],
#  [('동물원', 'Noun'),
#   ('이', 'Josa'),
#   ('있는', 'Adjective'),
#   ('수목원', 'Noun'),
#   ('보통', 'Noun'),
#   ('수목원', 'Noun'),
#   ('하면', 'Verb'),
#   ('나무', 'Noun'),
#   ('가', 'Josa'),
#   ('많은', 'Adjective'),
#   ('곳', 'Noun'),
#   ('또는', 'Adverb'),
#   ('숲', 'Noun'),
#   ('을', 'Josa'),
#   ('생각', 'Noun'),
#   ('하는데', 'Verb'),
#   ('이', 'Determiner'),
#   ('곳', 'Noun'),
#   ('은', 'Josa'),
#   ('동물원', 'Noun'),
#   ('도', 'Josa'),
#   ('있고', 'Adjective'),
#   ('각종', 'Noun'),
#   ('체험', 'Noun'),
#   ('거리', 'Noun'),
#   ('가', 'Josa'),
#   ('있는', 'Adjective'),
#   ('수목원', 'Noun'),
#   ('이다', 'Josa'),
#   ('불빛', 'Noun'),
#   ('축제', 'Noun'),
#   ('할', 'Verb'),
#   ('때', 'Noun'),
#   ('가면', 'Noun'),
#   ('더', 'Noun'),
#   ('좋은', 'Adjective'),
#   ('곳', 'Noun'),
#   ('이다', 'Josa')],
#  [('봄', 'Noun'),
#   ('이나', 'Josa'),
#   ('가을', 'Noun'),
#   ('에', 'Josa'),
#   ('가세', 'Noun'),
#   ('요', 'Josa'),
#   ('꽃', 'Noun'),
#   ('이', 'Josa'),
#   ('피는', 'Verb'),
#   ('봄', 'Noun'),
#   ('가을', 'Noun'),
#   ('에는', 'Josa'),
#   ('매우', 'Noun'),
#   ('아름답습니다', 'Adjective'),
#   ('구석', 'Noun'),
#   ('구석', 'Noun'),
#   ('세심', 'Noun'),
#   ('하게', 'Verb'),
#   ('꾸며진', 'Verb'),
#   ('정원', 'Noun'),
#   ('이', 'Josa'),
#   ('예쁘구요', 'Adjective'),
#   ('들어가는', 'Verb'),
#   ('곳', 'Noun'),
#   ('에도', 'Josa'),
#   ('맛집', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('많아', 'Adjective'),
#   ('좋습니다만', 'Adjective'),
#   ('항상', 'Noun'),
#   ('들어가는', 'Verb'),
#   ('길목', 'Noun'),
#   ('이', 'Josa'),
#   ('좁아', 'Adjective'),
#   ('위태', 'Noun'),
#   ('하긴', 'Verb'),
#   ('한데', 'Eomi'),
#   ('그건', 'Adverb'),
#   ('개선', 'Noun'),
#   ('되었으면', 'Verb'),
#   ('합니다', 'Verb'),
#   ('향수', 'Noun'),
#   ('나', 'Josa'),
#   ('물건', 'Noun'),
#   ('파는', 'Verb'),
#   ('곳도', 'Noun'),
#   ('예쁜', 'Adjective'),
#   ('물건', 'Noun'),
#   ('이', 'Josa'),
#   ('한가득', 'Adverb'),
#   ('입니다', 'Adjective')],
#  [('사계절', 'Noun'),
#   ('아름다운', 'Adjective'),
#   ('곳', 'Noun'),
#   ('아침', 'Noun'),
#   ('고요', 'Noun'),
#   ('수목원', 'Noun'),
#   ('은', 'Josa'),
#   ('봄', 'Noun'),
#   ('여름', 'Noun'),
#   ('가을', 'Noun'),
#   ('겨울', 'Noun'),
#   ('모두', 'Noun'),
#   ('각각', 'Noun'),
#   ('의', 'Josa'),
#   ('매력', 'Noun'),
#   ('이', 'Josa'),
#   ('넘칩니다', 'Adjective'),
#   ('주변', 'Noun'),
#   ('에', 'Josa'),
#   ('머무를만', 'Verb'),
#   ('한', 'Determiner'),
#   ('펜션', 'Noun'),
#   ('들', 'Suffix'),
#   ('도', 'Josa'),
#   ('많고', 'Adjective'),
#   ('맛집', 'Noun'),
#   ('들', 'Suffix'),
#   ('도', 'Josa'),
#   ('넘칩니다', 'Adjective'),
#   ('낭만', 'Noun'),
#   ('적', 'Suffix'),
#   ('인', 'Josa'),
#   ('시간', 'Noun'),
#   ('을', 'Josa'),
#   ('가지기에', 'Verb'),
#   ('좋은', 'Adjective'),
#   ('수목원', 'Noun'),
#   ('입니다', 'Adjective')],
#  [('너무', 'Adverb'),
#   ('예쁜', 'Adjective'),
#   ('곳', 'Noun'),
#   ('이에요', 'Josa'),
#   ('처음', 'Noun'),
#   ('엔', 'Josa'),
#   ('입장료', 'Noun'),
#   ('가', 'Josa'),
#   ('비싸다는', 'Adjective'),
#   ('생각', 'Noun'),
#   ('이', 'Josa'),
#   ('들었는데', 'Verb'),
#   ('정원', 'Noun'),
#   ('을', 'Josa'),
#   ('둘러보는데', 'Verb'),
#   ('너무', 'Adverb'),
#   ('정비', 'Noun'),
#   ('가', 'Josa'),
#   ('잘', 'Verb'),
#   ('되어', 'Verb'),
#   ('예쁘고', 'Adjective'),
#   ('그걸', 'Adverb'),
#   ('유지', 'Noun'),
#   ('하기', 'Verb'),
#   ('위해', 'Noun'),
#   ('많은', 'Adjective'),
#   ('분', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('수고', 'Noun'),
#   ('하시는', 'Verb'),
#   ('걸', 'Noun'),
#   ('보고', 'Noun'),
#   ('그런', 'Modifier'),
#   ('생각', 'Noun'),
#   ('은', 'Josa'),
#   ('사라졌어요', 'Verb'),
#   ('그리고', 'Conjunction'),
#   ('둘러보는', 'Verb'),
#   ('동안', 'Noun'),
#   ('힐링', 'Noun'),
#   ('이', 'Josa'),
#   ('되서', 'Verb'),
#   ('또', 'Noun'),
#   ('가고', 'Verb'),
#   ('싶네요', 'Verb')],
#  [('너무', 'Adverb'),
#   ('아름다워요', 'Adjective'),
#   ('수목원', 'Noun'),
#   ('이', 'Josa'),
#   ('굉장히', 'Adjective'),
#   ('큽니다', 'Verb'),
#   ('나무', 'Noun'),
#   ('와', 'Josa'),
#   ('꽃들이', 'Noun'),
#   ('풍', 'Adverb'),
#   ('성해서', 'Adjective'),
#   ('더욱', 'Noun'),
#   ('좋았어요', 'Adjective'),
#   ('비오는', 'Verb'),
#   ('날', 'Noun'),
#   ('도', 'Josa'),
#   ('좋고', 'Adjective'),
#   ('맑은', 'Noun'),
#   ('날', 'Noun'),
#   ('도', 'Josa'),
#   ('흐린', 'Verb'),
#   ('날', 'Noun'),
#   ('도', 'Josa'),
#   ('좋습니다', 'Adjective'),
#   ('수목원', 'Noun'),
#   ('내', 'Noun'),
#   ('에', 'Josa'),
#   ('식당', 'Noun'),
#   ('도', 'Josa'),
#   ('있고', 'Adjective'),
#   ('다양한', 'Adjective'),
#   ('물건', 'Noun'),
#   ('들', 'Suffix'),
#   ('을', 'Josa'),
#   ('살', 'Noun'),
#   ('수', 'Noun'),
#   ('있는', 'Adjective'),
#   ('대형숍', 'Noun'),
#   ('도', 'Josa'),
#   ('있어요', 'Adjective'),
#   ('반나절', 'Noun'),
#   ('은', 'Josa'),
#   ('보낸다고', 'Verb'),
#   ('생각', 'Noun'),
#   ('해야', 'Verb'),
#   ('할', 'Verb'),
#   ('것', 'Noun'),
#   ('입니다', 'Adjective')],
#  [('공기', 'Noun'),
#   ('좋은', 'Adjective'),
#   ('아침', 'Noun'),
#   ('고요', 'Noun'),
#   ('수목원', 'Noun'),
#   ('미세먼지', 'Noun'),
#   ('없는', 'Adjective'),
#   ('주말', 'Noun'),
#   ('에', 'Josa'),
#   ('애', 'Noun'),
#   ('들', 'Suffix'),
#   ('데리', 'Noun'),
#   ('고', 'Josa'),
#   ('산책', 'Noun'),
#   ('다녀오기', 'Verb'),
#   ('좋은', 'Adjective'),
#   ('곳', 'Noun'),
#   ('입니다', 'Adjective'),
#   ('나무', 'Noun'),
#   ('들', 'Suffix'),
#   ('과', 'Josa'),
#   ('꽃들이', 'Noun'),
#   ('많아서', 'Adjective'),
#   ('공기', 'Noun'),
#   ('가', 'Josa'),
#   ('정말', 'Noun'),
#   ('좋아요', 'Adjective'),
#   ('제법', 'Noun'),
#   ('많이', 'Adverb'),
#   ('걸어', 'Verb'),
#   ('다녀야', 'Verb'),
#   ('하는', 'Verb'),
#   ('게', 'Noun'),
#   ('어린이', 'Noun'),
#   ('들', 'Suffix'),
#   ('에게는', 'Josa'),
#   ('좀', 'Noun'),
#   ('힘들지만', 'Adjective'),
#   ('운동', 'Noun'),
#   ('이라', 'Josa'),
#   ('생각', 'Noun'),
#   ('하고', 'Josa'),
#   ('다녔습니다', 'Verb'),
#   ('사진', 'Noun'),
#   ('찍기', 'Noun'),
#   ('좋은', 'Adjective'),
#   ('장소', 'Noun'),
#   ('도', 'Josa'),
#   ('제법', 'Noun'),
#   ('많네요', 'Adjective')],
#  [('서울', 'Noun'),
#   ('근교', 'Noun'),
#   ('힐링', 'Noun'),
#   ('하기', 'Verb'),
#   ('좋은', 'Adjective'),
#   ('곳', 'Noun'),
#   ('서울', 'Noun'),
#   ('근교', 'Noun'),
#   ('에', 'Josa'),
#   ('조용하게', 'Adjective'),
#   ('힐링', 'Noun'),
#   ('할', 'Verb'),
#   ('수', 'Noun'),
#   ('있는', 'Adjective'),
#   ('곳', 'Noun'),
#   ('이다', 'Josa'),
#   ('처음', 'Noun'),
#   ('엔', 'Josa'),
#   ('입장료', 'Noun'),
#   ('가', 'Josa'),
#   ('비싸다고', 'Adjective'),
#   ('생각', 'Noun'),
#   ('했는데', 'Verb'),
#   ('안', 'Noun'),
#   ('에', 'Josa'),
#   ('꾸며져', 'Verb'),
#   ('있는', 'Adjective'),
#   ('정원', 'Noun'),
#   ('들', 'Suffix'),
#   ('을', 'Josa'),
#   ('보면', 'Verb'),
#   ('돈', 'Noun'),
#   ('이', 'Josa'),
#   ('아깝지', 'Adjective'),
#   ('않다', 'Verb'),
#   ('그리고', 'Conjunction'),
#   ('그', 'Noun'),
#   ('걸', 'Noun'),
#   ('유지', 'Noun'),
#   ('하기', 'Verb'),
#   ('위해', 'Noun'),
#   ('많은', 'Adjective'),
#   ('사람', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('쉼', 'Verb'),
#   ('없이', 'Adverb'),
#   ('애쓰고', 'Verb'),
#   ('있다', 'Adjective'),
#   ('계절', 'Noun'),
#   ('마다', 'Josa'),
#   ('다른', 'Noun'),
#   ('풍경', 'Noun'),
#   ('을', 'Josa'),
#   ('볼', 'Noun'),
#   ('수', 'Noun'),
#   ('있으니', 'Adjective'),
#   ('아무', 'Modifier'),
#   ('때', 'Noun'),
#   ('나', 'Josa'),
#   ('가도', 'Noun'),
#   ('좋다', 'Adjective')],
#  [('비', 'Noun'),
#   ('온', 'Noun'),
#   ('다음', 'Noun'),
#   ('날', 'Noun'),
#   ('은', 'Josa'),
#   ('기분', 'Noun'),
#   ('전환', 'Noun'),
#   ('하기', 'Verb'),
#   ('좋아요', 'Adjective'),
#   ('비', 'Noun'),
#   ('오고', 'Verb'),
#   ('다음', 'Noun'),
#   ('날', 'Noun'),
#   ('갔는데', 'Verb'),
#   ('수목원', 'Noun'),
#   ('전체', 'Noun'),
#   ('에서', 'Josa'),
#   ('풀향', 'Noun'),
#   ('에', 'Josa'),
#   ('은은하게', 'Adjective'),
#   ('퍼져서', 'Verb'),
#   ('상쾌하게', 'Adjective'),
#   ('기분', 'Noun'),
#   ('전환', 'Noun'),
#   ('이', 'Josa'),
#   ('됐습니다', 'Verb'),
#   ('다양한', 'Adjective'),
#   ('식물', 'Noun'),
#   ('과', 'Josa'),
#   ('산책로', 'Noun'),
#   ('가', 'Josa'),
#   ('있어', 'Adjective'),
#   ('좋습니다', 'Adjective'),
#   ('비', 'Noun'),
#   ('온', 'Noun'),
#   ('다음', 'Noun'),
#   ('날', 'Noun'),
#   ('가시는', 'Verb'),
#   ('걸', 'Noun'),
#   ('추천', 'Noun'),
#   ('합니다', 'Verb')],
#  [('워낙', 'Noun'),
#   ('유명한', 'Adjective'),
#   ('곳', 'Noun'),
#   ('이라', 'Josa'),
#   ('기대', 'Noun'),
#   ('가', 'Josa'),
#   ('엄청', 'Adverb'),
#   ('컸나', 'Verb'),
#   ('조카', 'Noun'),
#   ('입대', 'Noun'),
#   ('후', 'Noun'),
#   ('외박', 'Noun'),
#   ('면회', 'Noun'),
#   ('간김', 'Noun'),
#   ('에', 'Josa'),
#   ('가까운', 'Adjective'),
#   ('곳', 'Noun'),
#   ('관광', 'Noun'),
#   ('차', 'Noun'),
#   ('들렀던', 'Verb'),
#   ('아침', 'Noun'),
#   ('고요', 'Noun'),
#   ('수목원', 'Noun'),
#   ('워낙', 'Noun'),
#   ('유명한', 'Adjective'),
#   ('곳', 'Noun'),
#   ('이라', 'Josa'),
#   ('기대', 'Noun'),
#   ('가', 'Josa'),
#   ('엄청', 'Adverb'),
#   ('컸', 'Verb'),
#   ('나기', 'Noun'),
#   ('대', 'Suffix'),
#   ('만큼', 'Josa'),
#   ('아닌듯', 'Adjective')],
#  [('동해', 'Noun'),
#   ('무릉', 'Noun'),
#   ('건강', 'Noun'),
#   ('숲', 'Noun'),
#   ('으로', 'Josa'),
#   ('오면', 'Verb'),
#   ('동해', 'Noun'),
#   ('무릉', 'Noun'),
#   ('건강', 'Noun'),
#   ('숲', 'Noun'),
#   ('으로', 'Josa'),
#   ('왔을', 'Verb'),
#   ('때', 'Noun'),
#   ('가', 'Verb'),
#   ('봤어요', 'Verb'),
#   ('경치', 'Noun'),
#   ('가', 'Josa'),
#   ('좋고', 'Adjective'),
#   ('깨끗한', 'Adjective'),
#   ('곳', 'Noun'),
#   ('이네', 'Josa'),
#   ('요', 'Noun'),
#   ('여름', 'Noun'),
#   ('에', 'Josa'),
#   ('힐링', 'Noun'),
#   ('하기에', 'Verb'),
#   ('딱', 'Adverb'),
#   ('좋아요', 'Adjective'),
#   ('추천', 'Noun'),
#   ('웰', 'Noun'),
#   ('니스', 'Noun'),
#   ('관광지', 'Noun'),
#   ('한국', 'Noun'),
#   ('관광', 'Noun'),
#   ('공사', 'Noun')],
#  [('겨울', 'Noun'),
#   ('보다는', 'Josa'),
#   ('봄', 'Noun'),
#   ('여름', 'Noun'),
#   ('가을', 'Noun'),
#   ('에', 'Josa'),
#   ('무릉', 'Noun'),
#   ('계곡', 'Noun'),
#   ('여름', 'Noun'),
#   ('사진', 'Noun'),
#   ('들', 'Suffix'),
#   ('을', 'Josa'),
#   ('보고', 'Noun'),
#   ('너무', 'Adverb'),
#   ('가보고', 'Verb'),
#   ('싶어서', 'Verb'),
#   ('갔는데', 'Verb'),
#   ('겨울', 'Noun'),
#   ('이라', 'Josa'),
#   ('그런지', 'Adjective'),
#   ('크게', 'Noun'),
#   ('만족스럽진', 'Adjective'),
#   ('않았어요', 'Verb'),
#   ('눈', 'Noun'),
#   ('이', 'Josa'),
#   ('온', 'Noun'),
#   ('뒤', 'Noun'),
#   ('좀', 'Noun'),
#   ('더', 'Noun'),
#   ('멋질', 'Adjective'),
#   ('것', 'Noun'),
#   ('같은', 'Adjective'),
#   ('공간', 'Noun'),
#   ('이지만', 'Josa'),
#   ('폭포', 'Noun'),
#   ('에도', 'Josa'),
#   ('물이', 'Noun'),
#   ('나', 'Josa'),
#   ('얼음', 'Noun'),
#   ('언', 'Modifier'),
#   ('것', 'Noun'),
#   ('도', 'Josa'),
#   ('없고', 'Adjective'),
#   ('해서', 'Verb'),
#   ('좀', 'Noun'),
#   ('심심했습니다', 'Adjective'),
#   ('그래도', 'Adverb'),
#   ('주차장', 'Noun'),
#   ('에서', 'Josa'),
#   ('길이', 'Noun'),
#   ('잘', 'VerbPrefix'),
#   ('되어', 'Verb'),
#   ('있는', 'Adjective'),
#   ('편이', 'Noun'),
#   ('고', 'Josa'),
#   ('편의', 'Noun'),
#   ('시설', 'Noun'),
#   ('들', 'Suffix'),
#   ('은', 'Josa'),
#   ('충분히', 'Adjective'),
#   ('잘', 'Verb'),
#   ('되어', 'Verb'),
#   ('있더군요', 'Adjective'),
#   ('공기', 'Noun'),
#   ('좋고', 'Adjective'),
#   ('암', 'Modifier'),
#   ('반', 'Noun'),
#   ('계곡', 'Noun'),
#   ('길이', 'Noun'),
#   ('장엄해서', 'Adjective'),
#   ('잠깐', 'Noun'),
#   ('들려서', 'Verb'),
#   ('보기', 'Noun'),
#   ('에는', 'Josa'),
#   ('괜찮은', 'Adjective'),
#   ('것', 'Noun'),
#   ('같습니다', 'Adjective'),
#   ('초여름', 'Noun'),
#   ('쯤', 'Suffix'),
#   ('다시', 'Noun'),
#   ('방문', 'Noun'),
#   ('해야', 'Verb'),
#   ('할', 'Verb'),
#   ('것', 'Noun'),
#   ('같습니다', 'Adjective')],
#  [('신선', 'Noun'),
#   ('이', 'Josa'),
#   ('나올것', 'Verb'),
#   ('같은', 'Adjective'),
#   ('옛날', 'Noun'),
#   ('부터', 'Josa'),
#   ('사진', 'Noun'),
#   ('으로만', 'Josa'),
#   ('봤는데', 'Verb'),
#   ('더운', 'Adjective'),
#   ('여름', 'Noun'),
#   ('에', 'Josa'),
#   ('물놀이', 'Noun'),
#   ('하러', 'Verb'),
#   ('갔다', 'Verb'),
#   ('왔습니다', 'Verb'),
#   ('교통', 'Noun'),
#   ('이', 'Josa'),
#   ('불편하긴', 'Adjective'),
#   ('하지만', 'Conjunction'),
#   ('경치', 'Noun'),
#   ('랑', 'Josa'),
#   ('딱', 'Adverb'),
#   ('놀기', 'Verb'),
#   ('좋은', 'Adjective'),
#   ('계곡', 'Noun'),
#   ('최고', 'Noun'),
#   ('였습니다', 'Verb')],
#  [('뜨거운', 'Adjective'),
#   ('정오', 'Noun'),
#   ('추천', 'Noun'),
#   ('입장료', 'Noun'),
#   ('내고', 'Verb'),
#   ('들어가서', 'Verb'),
#   ('조금', 'Noun'),
#   ('걸으니', 'Verb'),
#   ('물놀이', 'Noun'),
#   ('광경', 'Noun'),
#   ('이', 'Josa'),
#   ('펼쳐져요', 'Verb'),
#   ('아이', 'Noun'),
#   ('들', 'Suffix'),
#   ('신남', 'Adjective'),
#   ('그리고', 'Conjunction'),
#   ('사찰', 'Noun'),
#   ('이보', 'Noun'),
#   ('이고', 'Josa'),
#   ('등산로', 'Noun'),
#   ('도', 'Josa'),
#   ('있어요', 'Adjective'),
#   ('많이', 'Adverb'),
#   ('걷지', 'Verb'),
#   ('않아도', 'Verb'),
#   ('바로', 'Noun'),
#   ('풍경', 'Noun'),
#   ('이', 'Josa'),
#   ('펼쳐지니', 'Verb'),
#   ('좋이', 'Adjective'),
#   ('ㅣ', 'KoreanParticle'),
#   ('요', 'Modifier'),
#   ('가족', 'Noun'),
#   ('끼리', 'Noun'),
#   ('도', 'Josa'),
#   ('연인', 'Noun'),
#   ('끼리', 'Noun'),
#   ('도', 'Josa'),
#   ('칭구', 'Noun'),
#   ('와도', 'Josa'),
#   ('추천', 'Noun'),
#   ('합니다', 'Verb')],
#  [('판타지', 'Noun'),
#   ('스러운', 'Adjective'),
#   ('곳', 'Noun'),
#   ('이름', 'Noun'),
#   ('에서부터', 'Josa'),
#   ('판타지', 'Noun'),
#   ('스러운', 'Josa'),
#   ('곳', 'Noun'),
#   ('혼자', 'Noun'),
#   ('겨울', 'Noun'),
#   ('여행', 'Noun'),
#   ('갔다', 'Verb'),
#   ('잠시', 'Noun'),
#   ('들려', 'Verb'),
#   ('그', 'Noun'),
#   ('매력', 'Noun'),
#   ('에', 'Josa'),
#   ('빠졌다', 'Verb'),
#   ('천천히', 'Adverb'),
#   ('것', 'Noun'),
#   ('다', 'Adverb'),
#   ('나오는', 'Verb'),
#   ('삼화사', 'Noun'),
#   ('가', 'Josa'),
#   ('매력', 'Noun'),
#   ('적', 'Noun'),
#   ('인', 'Josa'),
#   ('곳', 'Noun'),
#   ('아주', 'Noun'),
#   ('좋다', 'Adjective')],
#  [('어릴', 'Verb'),
#   ('적나의', 'Verb'),
#   ('놀이터', 'Noun'),
#   ('어릴', 'Verb'),
#   ('적', 'Noun'),
#   ('정말', 'Noun'),
#   ('많이', 'Adverb'),
#   ('갔던', 'Verb'),
#   ('곳', 'Noun'),
#   ('암', 'Modifier'),
#   ('반', 'Modifier'),
#   ('계곡', 'Noun'),
#   ('이', 'Josa'),
#   ('정말', 'Noun'),
#   ('멋진', 'Adjective'),
#   ('곳', 'Noun'),
#   ('닭백숙', 'Noun'),
#   ('산채', 'Noun'),
#   ('비빔밥', 'Noun'),
#   ('감자전', 'Noun'),
#   ('도토리묵', 'Noun'),
#   ('등', 'Noun'),
#   ('맛집', 'Noun'),
#   ('이', 'Josa'),
#   ('많은주', 'Adjective'),
#   ('차비', 'Noun'),
#   ('입장료', 'Noun'),
#   ('있음', 'Adjective'),
#   ('후회', 'Noun'),
#   ('없는', 'Adjective'),
#   ('여행', 'Noun'),
#   ('일것', 'Verb'),
#   ('입니다', 'Adjective')],
#  [('스케일', 'Noun'),
#   ('이', 'Josa'),
#   ('큰', 'Verb'),
#   ('멋진', 'Adjective'),
#   ('풍경', 'Noun'),
#   ('글자', 'Noun'),
#   ('가', 'Josa'),
#   ('새겨진', 'Verb'),
#   ('계곡', 'Noun'),
#   ('은', 'Josa'),
#   ('크고', 'Verb'),
#   ('넓어서', 'Adjective'),
#   ('바위', 'Noun'),
#   ('위', 'Noun'),
#   ('에', 'Josa'),
#   ('서', 'Verb'),
#   ('있으면', 'Adjective'),
#   ('고', 'Modifier'),
#   ('즈', 'Modifier'),
#   ('넉', 'Noun'),
#   ('하고', 'Josa'),
#   ('광활한', 'Adjective'),
#   ('느낌', 'Noun'),
#   ('이', 'Josa'),
#   ('듭니', 'Noun'),
#   ('다', 'Josa'),
#   ('가까운', 'Adjective'),
#   ('곳', 'Noun'),
#   ('의', 'Josa'),
#   ('사찰', 'Noun'),
#   ('도', 'Josa'),
#   ('풍경', 'Noun'),
#   ('이', 'Josa'),
#   ('멋집니다', 'Adjective'),
#   ('많이', 'Adverb'),
#   ('걷지', 'Verb'),
#   ('않아도', 'Verb'),
#   ('계곡', 'Noun'),
#   ('이', 'Josa'),
#   ('가까이', 'Noun'),
#   ('있고', 'Adjective'),
#   ('원하면', 'Adjective'),
#   ('숲길', 'Noun'),
#   ('사이', 'Noun'),
#   ('로', 'Josa'),
#   ('좀', 'Noun'),
#   ('더', 'Noun'),
#   ('멀리', 'Noun'),
#   ('하이킹', 'Noun'),
#   ('을', 'Josa'),
#   ('할', 'Verb'),
#   ('수', 'Noun'),
#   ('있습니다', 'Adjective'),
#   ('겨울', 'Noun'),
#   ('에', 'Josa'),
#   ('가니', 'Verb'),
#   ('가게', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('문', 'Noun'),
#   ('을', 'Josa'),
#   ('거의', 'Noun'),
#   ('닫아', 'Verb'),
#   ('을', 'Josa'),
#   ('씨년', 'Noun'),
#   ('스럽', 'Adjective'),
#   ('기도', 'Noun'),
#   ('한데', 'Eomi'),
#   ('살얼음', 'Noun'),
#   ('덮힌', 'Noun'),
#   ('계곡', 'Noun'),
#   ('이나', 'Josa'),
#   ('잔설', 'Noun'),
#   ('이', 'Josa'),
#   ('남은', 'Verb'),
#   ('숲', 'Noun'),
#   ('등', 'Noun'),
#   ('멋진', 'Adjective'),
#   ('풍경', 'Noun'),
#   ('을', 'Josa'),
#   ('만날', 'Noun'),
#   ('수', 'Noun'),
#   ('있습니다', 'Adjective')],
#  [('꼭', 'Noun'),
#   ('한번', 'Noun'),
#   ('가보고싶은', 'Verb'),
#   ('곳', 'Noun'),
#   ('무더운', 'Adjective'),
#   ('여름철', 'Noun'),
#   ('아이', 'Noun'),
#   ('들', 'Suffix'),
#   ('계곡', 'Noun'),
#   ('물놀이', 'Noun'),
#   ('로', 'Josa'),
#   ('다녀왔어요', 'Verb'),
#   ('넓은', 'Adjective'),
#   ('반석', 'Noun'),
#   ('이', 'Josa'),
#   ('펼쳐있어', 'Verb'),
#   ('아이', 'Noun'),
#   ('들', 'Suffix'),
#   ('이', 'Josa'),
#   ('튜브', 'Noun'),
#   ('로', 'Josa'),
#   ('미끄럼', 'Noun'),
#   ('물놀이', 'Noun'),
#   ('를', 'Josa'),
#   ('즐길수있으나', 'Verb'),
#   ('걷기', 'Noun'),
#   ('에', 'Josa'),
#   ('너무', 'Adverb'),
#   ('미끄럽네요', 'Adjective'),
#   ('넘어지기', 'Verb'),
#   ('쉬어', 'Verb'),
#   ('아주', 'Noun'),
#   ('어린이', 'Noun'),
#   ('나', 'Josa'),
#   ('노인', 'Noun'),
#   ('은', 'Josa'),
#   ('좀', 'Noun'),
#   ('위험해요', 'Adjective'),
#   ('계곡', 'Noun'),
#   ('보다', 'Josa'),
#   ('다음', 'Noun'),
#   ('번', 'Noun'),
#   ('에는', 'Josa'),
#   ('등산', 'Noun'),
#   ('을', 'Josa'),
#   ('위해', 'Noun'),
#   ('서', 'Josa'),
#   ('방문', 'Noun'),
#   ('해보고싶어요', 'Verb')],
#  ...]

# %%
noun_list=[]
for sentence in sentences_tag:
    for word,tag in sentence:
        if tag in ['Noun']:
            noun_list.append(word)

# %%
len(noun_list)

noun_list=[n for n in noun_list if len(n) > 1]
noun_list[:100]
# Out:
# ['대한민국',
#  '역사',
#  '대한민국',
#  '역사',
#  '서울',
#  '방문',
#  '방문',
#  '경복궁',
#  '우리',
#  '역사',
#  '경복궁',
#  '산책',
#  '행복',
#  '국민',
#  '공감',
#  '장소',
#  '경복궁',
#  '국민',
#  '자주',
#  '작성자',
#  '주말',
#  '자주',
#  '가족',
#  '방문',
#  '가족',
#  '방문',
#  '고궁',
#  '공기',
#  '역사',
#  '체험',
#  '힐링',
#  '곳임',
#  '산책',
#  '경복궁',
#  '날씨',
#  '종종',
#  '산책',
#  '경복궁',
#  '마음',
#  '해지',
#  '기분',
#  '가을',
#  '산책',
#  '추천',
#  '다음',
#  '근처',
#  '관광지',
#  '거리',
#  '자주',
#  '이용',
#  '가족',
#  '위로',
#  '방문',
#  '요새',
#  '더욱',
#  '코로나',
#  '사람',
#  '방문',
#  '자녀',
#  '반시',
#  '성인',
#  '입장',
#  '무료',
#  '지금',
#  '시기',
#  '나들이',
#  '지하철',
#  '광화문역',
#  '종각역',
#  '이용',
#  '편리',
#  '하늘',
#  '조선',
#  '개국',
#  '처음',
#  '세운',
#  '으뜸',
#  '궁궐',
#  '하늘',
#  '경복궁',
#  '웅장',
#  '경복궁',
#  '임진왜란',
#  '일제강점기',
#  '일본',
#  '파괴',
#  '당한',
#  '악연',
#  '향원정',
#  '보수',
#  '공사',
#  '경회루',
#  '경복궁',
#  '한국',
#  '건축물',
#  '한복',
#  '입장료',
#  '무료',
#  '주변',
#  '한복']

# %%
counts=Counter(noun_list)
tags=counts.most_common(70)
tags
# Out:
# [('방문', 1219),
#  ('아이', 799),
#  ('박물관', 789),
#  ('산책', 762),
#  ('시간', 676),
#  ('사람', 650),
#  ('생각', 650),
#  ('공원', 604),
#  ('역사', 564),
#  ('추천', 560),
#  ('정말', 550),
#  ('가족', 500),
#  ('바다', 489),
#  ('사진', 453),
#  ('장소', 421),
#  ('정도', 404),
#  ('한번', 395),
#  ('코스', 391),
#  ('입장료', 370),
#  ('사찰', 357),
#  ('구경', 355),
#  ('체험', 347),
#  ('주변', 347),
#  ('여행', 335),
#  ('가을', 333),
#  ('가면', 327),
#  ('느낌', 320),
#  ('위치', 319),
#  ('풍경', 305),
#  ('한국', 301),
#  ('조금', 301),
#  ('마을', 289),
#  ('근처', 288),
#  ('전시', 282),
#  ('주차장', 282),
#  ('서울', 280),
#  ('모습', 275),
#  ('건물', 270),
#  ('경치', 262),
#  ('아주', 255),
#  ('보고', 249),
#  ('여름', 241),
#  ('매우', 239),
#  ('하나', 237),
#  ('주차', 236),
#  ('입구', 236),
#  ('다른', 234),
#  ('가장', 232),
#  ('길이', 230),
#  ('무료', 229),
#  ('거리', 225),
#  ('겨울', 224),
#  ('규모', 222),
#  ('가기', 212),
#  ('볼거리', 210),
#  ('타고', 206),
#  ('계곡', 206),
#  ('바로', 204),
#  ('바람', 204),
#  ('자연', 203),
#  ('날씨', 199),
#  ('나무', 199),
#  ('우리', 198),
#  ('마음', 197),
#  ('최고', 197),
#  ('이용', 195),
#  ('그냥', 192),
#  ('단풍', 191),
#  ('힐링', 183),
#  ('관람', 183)]

# %%
tags.remove(('방문', 1219))
tags.remove(('정도', 404))
tags.remove(('한국', 301))
tags.remove(('아주', 255))
tags.remove(('매우', 239))
tags.remove(('다른', 234))
tags.remove(('가장', 232))

# %%
from PIL import Image
image=Image.open('cloud_img.jpg')
mask=np.array(image)

# %%
## 워드 클라우드 생성
font_path='C:/Windows/Fonts/HMFMOLD.ttf'
from wordcloud import WordCloud
wordcloud=WordCloud(font_path=font_path,
                   background_color='Black',width=900,height=700,colormap='spring',mask=mask)

print(dict(tags))
# Out:
# {'아이': 799, '박물관': 789, '산책': 762, '시간': 676, '사람': 650, '생각': 650, '공원': 604, '역사': 564, '추천': 560, '정말': 550, '가족': 500, '바다': 489, '사진': 453, '장소': 421, '한번': 395, '코스': 391, '입장료': 370, '사찰': 357, '구경': 355, '체험': 347, '주변': 347, '여행': 335, '가을': 333, '가면': 327, '느낌': 320, '위치': 319, '풍경': 305, '조금': 301, '마을': 289, '근처': 288, '전시': 282, '주차장': 282, '서울': 280, '모습': 275, '건물': 270, '경치': 262, '보고': 249, '여름': 241, '하나': 237, '주차': 236, '입구': 236, '길이': 230, '무료': 229, '거리': 225, '겨울': 224, '규모': 222, '가기': 212, '볼거리': 210, '타고': 206, '계곡': 206, '바로': 204, '바람': 204, '자연': 203, '날씨': 199, '나무': 199, '우리': 198, '마음': 197, '최고': 197, '이용': 195, '그냥': 192, '단풍': 191, '힐링': 183, '관람': 183}

# %%
cloud=wordcloud.generate_from_frequencies(dict(tags))
plt.figure(figsize=(10,8))
plt.axis('off')
plt.imshow(cloud)
plt.show()

# %%
df.head()
# Out:
#    관광지                                               전체내용
# 0  경복궁  대한민국의 역사  대한민국의 역사가 잠들어 있는 곳 서울을 방문했다면 꼭 방문해야 ...
# 1  경복궁  국민이 공감하는 장소  경복궁은 국민들이 자주 찾는곳으로 작성자는 주말에 자주 가족...
# 2  경복궁  산책하기 좋은 경복궁  날씨 좋은 날 종종 산책하러 경복궁에 가는데 마음이 편온해지...
# 3  경복궁     다 좋습니다 다음에 또 오고 싶네요 근처 관광지도많고 먹을거리도많네요 서울올때...
# 4  경복궁  가족단위로 방문하기 좋은곳  요새 더더욱 코로나로 인해 사람 방문이 적음 두자녀 동...

# %%
df2.head()
# Out:
#                 여행지  카테고리
# 0             63스퀘어  랜드마크
# 1           BIFF 광장  랜드마크
# 2  SEA LIFE 부산아쿠아리움  랜드마크
# 3          가야산 국립공원    공원
# 4               간월재     산

# %%
df2['카테고리'].unique()
# Out:
# array(['랜드마크', '공원', '산', '역사적인 장소', '종교적인 장소', '박물관', '자연 경관', '지층',
#        '해변', '행사', '섬', '리조트'], dtype=object)

# %%
lists=['63빌딩','가야산 국립공원','경복궁']
if df['관광지'][0] in lists:
    print('있음')
else:
    print('없음')
# Out:
# 있음

# %%
df['관광지'][0] in lists
# Out:
# True

# %%
# 랜드마크 : landmarks
df_a=df2[df2['카테고리']=='랜드마크']
df_a['여행지'].unique()
# Out:
# array(['63스퀘어', 'BIFF 광장', 'SEA LIFE 부산아쿠아리움', '간절곶', '강촌', '강화 풍물시장',
#        '거북선모형관', '경천대', '고추장마을', '광안대교', '광한루원', '구암리 지석묘 무리', '구인사',
#        '그림이 있는 정원', '금강 철새조망대', '기장시장', '김녕 미로공원', '나주 영상테마파크',
#        '낙동강 옛 철교', '낙동강하구에코센터', '남대문시장', '남사 예담촌', '남사당 전수관', '남산과 N서울타워',
#        '누리마루 APEC 하우스', '다랭이마을', '대관령 삼양목장', '대기리 고랭지 채소밭',
#        '대한민국 국회의사당과 헌정기념관', '덕구온천 스파월드', '독락당', '동대문디자인플라자', '동대문시장',
#        '두륜산 케이블카', '땅끝마을', '롯데월드', '명동', '문경 철로 자전거', '문경 활공랜드', '문장대',
#        '밀양 얼음골', '바람의 언덕', '벌교 홍교, 대한다원', '별마로천문대', '보림사', '보수동 책방골목',
#        '봉화의 약수', '부산타워', '부안 영상테마파크', '북촌한옥마을', '산수유마을', '삼강주막', '삼청동길',
#        '서대문형무소', '서울 약령시장', '서울광장', '선비촌', '설악 씨네라마', '섬진강 기차마을', '세리월드',
#        '세병관', '소래포구', '소설  『토지』 촬영장(최 참판 댁)', '소인국 테마파크', '속초 등대전망대',
#        '송천 떡마을', '순천 드라마세트장 ', '신선대', '아바이마을', '아인스월드', '안민도로', '안흥찐빵마을',
#        '애기봉전망대', '양떼목장', '에버랜드', '영금정', '오두산 통일전망대', '오설록뮤지엄', '올림픽공원',
#        '외도 해상농원', '외암민속마을', '원당 허브랜드', '이화벽화마을', '익산 왕궁리 오층석탑', '인사동길',
#        '임실치즈테마파크', '자갈치시장', '전주한옥마을', '제오리 공룡 발자국 화석', '죽서루', '중미산천문대',
#        '지리산 산수유마을', '진도타워', '차이나타운', '철암역', '청계천', '청사포', '청와대', '테르메덴온천',
#        '통일전망대', '파주 프로방스', '팔공산케이블카', '퍼시픽랜드', '풍수원성당', '한드미마을',
#        '합천 영상테마파크', '해운대 달맞이길', '해저터널', '헤이리 문화예술마을', '환선굴'], dtype=object)

# %%
type(list(df_a['여행지'].unique()))
# Out:
# list

# %%
landmarks=list(df_a['여행지'].unique())

# %%
df2['카테고리'].unique()
# Out:
# array(['랜드마크', '공원', '산', '역사적인 장소', '종교적인 장소', '박물관', '자연 경관', '지층',
#        '해변', '행사', '섬', '리조트'], dtype=object)

# %%
# 공원 : parks
df_b=df2[df2['카테고리']=='공원']
parks=list(df_b['여행지'].unique())

# %%
parks
# Out:
# ['가야산 국립공원',
#  '강천산',
#  '거제 포로수용소 유적공원',
#  '경기도립 물향기수목원',
#  '경상남도수목원',
#  '경안천 습지생태공원',
#  '계룡산 국립공원',
#  '곰소염전',
#  '국립수목원',
#  '금강 공원',
#  '금오산',
#  '낙산공원',
#  '내장산 국립공원',
#  '달아공원',
#  '대나무골 테마공원',
#  '대왕암 공원',
#  '덕유산 국립공원',
#  '덕진공원',
#  '돌산대교와 돌산공원',
#  '무주 구천동계곡 방화동 가족휴양촌,',
#  '문경새재도립공원',
#  '민주공원',
#  '북촌 돌하르방공원',
#  '비자림',
#  '사직단',
#  '삼사 해상공원',
#  '상족암군립공원',
#  '서울대공원',
#  '서일농원',
#  '선유도',
#  '선유도공원',
#  '설악산 국립공원',
#  '속리산 국립공원',
#  '순천만 갈대밭',
#  '아차산북한산국립공원',
#  '아침고요수목원',
#  '안양 예술공원',
#  '여미지식물원',
#  '여의도공원',
#  '영덕 해맞이 공원',
#  '오대산 국립공원',
#  '옥포대첩기념공원',
#  '용두산공원',
#  '원당 종마목장',
#  '월드컵공원',
#  '월명공원',
#  '월악산 국립공원',
#  '유달산조각공원',
#  '음성 큰바위얼굴 조각공원',
#  '일산 호수공원',
#  '자유공원',
#  '제이드가든 수목원',
#  '제주돌문화공원',
#  '죽녹원',
#  '지리산 국립공원',
#  '창원 해양공원',
#  '치악산 국립공원',
#  '탑골공원',
#  '태백산도립공원',
#  '태화강 십리대밭',
#  '통영 남망산국제조각공원',
#  '팜카밀레 허브농원',
#  '한강시민공원',
#  '한라산 국립공원',
#  '한림공원',
#  '한택식물원',
#  '해신당공원',
#  '홍릉수목원',
#  '황매산 군립공원',
#  '휴애리 자연생활공원']

# %%
# 산 : mount
df_c=df2[df2['카테고리']=='산']
mounts=list(df_c['여행지'].unique())

# 역사적인 장소 : hist
df_c=df2[df2['카테고리']=='역사적인 장소']
hist=list(df_c['여행지'].unique())

# 종교적인 장소 : shamon
df_c=df2[df2['카테고리']=='종교적인 장소']
shamon=list(df_c['여행지'].unique())

# 박물관 : museum
df_c=df2[df2['카테고리']=='박물관']
museum=list(df_c['여행지'].unique())

# 자연 경관 : natural
df_c=df2[df2['카테고리']=='자연 경관']
natural=list(df_c['여행지'].unique())

# 지층 : clif
df_c=df2[df2['카테고리']=='지층']
clif=list(df_c['여행지'].unique())

# 해변 : beach
df_c=df2[df2['카테고리']=='해변']
beach=list(df_c['여행지'].unique())

# 행사 : festival
df_c=df2[df2['카테고리']=='행사']
festival=list(df_c['여행지'].unique())

# 섬 : islands
df_c=df2[df2['카테고리']=='섬']
islands=list(df_c['여행지'].unique())

# 리조트 : resort
df_c=df2[df2['카테고리']=='리조트']
resort=list(df_c['여행지'].unique())

# %%
resort
# Out:
# ['담양온천', '덕산 스파캐슬', '호텔미란다 스파플러스']

# %% [markdown]
# ### 각 카테고리에 해당하는 관광지는 리스트 형태로 정리했음
# - 랜드마크 : landmarks
# - 공원 : parks
# - 산 : mount
# - 역사적인 장소 : hist
# - 종교적인 장소 : shamon
# - 박물관 : museum
# - 자연 경관 : natural
# - 지층 : clif
# - 해변 : beach
# - 행사 : festival
# - 섬 : islands
# - 리조트 : resort

# %% [markdown]
# #### 랜드마크만 추출해보기

# %%
df.head()
# Out:
#    관광지                                               전체내용  카테고리
# 0  경복궁  대한민국의 역사  대한민국의 역사가 잠들어 있는 곳 서울을 방문했다면 꼭 방문해야 ...  랜드마크
# 1  경복궁  국민이 공감하는 장소  경복궁은 국민들이 자주 찾는곳으로 작성자는 주말에 자주 가족...  랜드마크
# 2  경복궁  산책하기 좋은 경복궁  날씨 좋은 날 종종 산책하러 경복궁에 가는데 마음이 편온해지...  랜드마크
# 3  경복궁     다 좋습니다 다음에 또 오고 싶네요 근처 관광지도많고 먹을거리도많네요 서울올때...  랜드마크
# 4  경복궁  가족단위로 방문하기 좋은곳  요새 더더욱 코로나로 인해 사람 방문이 적음 두자녀 동...  랜드마크

# %%
df=pd.read_csv('지이인짜최종리뷰데이터.csv')

# %%
df['카테고리']='X'

# %%
for i in range(len(df)):
    if df['관광지'][i] in landmarks:
        df['카테고리'][i]='랜드마크'
    elif df['관광지'][i] in parks:
        df['카테고리'][i]='공원'
    elif df['관광지'][i] in mounts:
        df['카테고리'][i]='산'  
    elif df['관광지'][i] in hist:
        df['카테고리'][i]='역사적인 장소'
    elif df['관광지'][i] in shamon:
        df['카테고리'][i]='종교적인 장소'
    elif df['관광지'][i] in museum:
        df['카테고리'][i]='박물관'
    elif df['관광지'][i] in natural:
        df['카테고리'][i]='자연 경관'
    elif df['관광지'][i] in clif:
        df['카테고리'][i]='지층'
    elif df['관광지'][i] in beach:
        df['카테고리'][i]='해변'
    elif df['관광지'][i] in festival:
        df['카테고리'][i]='행사'
    elif df['관광지'][i] in islands:
        df['카테고리'][i]='섬'
    elif df['관광지'][i] in resort:
        df['카테고리'][i]='리조트'

# %%
df
# Out:
#               관광지                                               전체내용     카테고리
# 0             경복궁  대한민국의 역사 : 대한민국의 역사가 잠들어 있는 곳. 서울을 방문했다면 꼭 방문해...  역사적인 장소
# 1             경복궁  국민이 공감하는 장소 : 경복궁은 국민들이 자주 찾는곳으로 작성자는 주말에 자주 가...  역사적인 장소
# 2             경복궁  산책하기 좋은 경복궁 : 날씨 좋은 날 종종 산책하러 경복궁에 가는데 마음이 편온해...  역사적인 장소
# 3             경복궁  Good : Goooooood 다 좋습니다 다음에 또 오고 싶네요 근처 관광지도많고...  역사적인 장소
# 4             경복궁  가족단위로 방문하기 좋은곳 : 요새 더더욱 코로나로 인해 사람 방문이 적음. 두자녀...  역사적인 장소
# ...           ...                                                ...      ...
# 5231  벌교 홍교, 대한다원  저는 녹차밭을 별로 기대하고 가지 않았습니다.. 처음에는 안 들리고 지나가려고 했었...     랜드마크
# 5232  벌교 홍교, 대한다원                                             보성 녹차밭     랜드마크
# 5233  벌교 홍교, 대한다원  참 멋지고 이쁘네요말로만듣고 이번에 가봤는데 좋았어요또 가보고싶었고요추천해요혼자갔는...     랜드마크
# 5234  벌교 홍교, 대한다원                              비오는 겨울 풍경도 아름다운 다원...     랜드마크
# 5235  벌교 홍교, 대한다원  비오는 겨울 다원 산책은 무모한 도전이었지만 또 다른 경험...다우너의 초록색은 없...     랜드마크
#
# [5236 rows x 3 columns]

# %%
a=df[df['카테고리']=='랜드마크']

# %%
okt=Okt() # 형태소 분석기
word_list=[]
word_list=a['전체내용']

# %%
sentences_tag=[]

for sentence in word_list:
    morph=okt.pos(sentence)
    sentences_tag.append(morph)

# %%
noun_list=[]
for sentence in sentences_tag:
    for word,tag in sentence:
        if tag in ['Noun']:
            noun_list.append(word)

# %%
len(noun_list)

noun_list=[n for n in noun_list if len(n) > 1]
noun_list[:100]
# Out:
# ['청와대',
#  '관람',
#  '투어',
#  '개월',
#  '예약',
#  '주말',
#  '가족',
#  '경복궁',
#  '항상',
#  '멀리',
#  '청와대',
#  '상징',
#  '경비',
#  '투어',
#  '화장실',
#  '청와대',
#  '관람차',
#  '보안',
#  '검색',
#  '기전',
#  '화장실',
#  '기념품',
#  '성인',
#  '머그컵',
#  '아이',
#  '버스',
#  '카드',
#  '목걸이',
#  '지갑',
#  '산책',
#  '햇빛',
#  '모자',
#  '생수',
#  '음료',
#  '정도',
#  '가세',
#  '청와대',
#  '내부',
#  '관람',
#  '사전예약',
#  '예약',
#  '경우',
#  '외부',
#  '전경',
#  '기념',
#  '촬영',
#  '청와대',
#  '대한민국',
#  '대통령',
#  '집무실',
#  '관저',
#  '청와대',
#  '앞길',
#  '최근',
#  '개방',
#  '느낌',
#  '청와대',
#  '약제',
#  '내부',
#  '예약',
#  '외곽',
#  '돌담',
#  '가을',
#  '낙엽',
#  '질때',
#  '청와대',
#  '청와대',
#  '관람',
#  '예약',
#  '경복궁',
#  '청와대',
#  '청와대',
#  '공원',
#  '개방',
#  '청와대',
#  '공원',
#  '둘러보기',
#  '추천',
#  '청와대',
#  '견학',
#  '예약',
#  '제로',
#  '운영',
#  '올해',
#  '청와대',
#  '공원',
#  '인근',
#  '검문',
#  '산책',
#  '청와대',
#  '공원',
#  '산책',
#  '청와대',
#  '삼청동',
#  '가치',
#  '예약',
#  '경비',
#  '사진',
#  '정해',
#  '불구']

# %%
counts=Counter(noun_list)
tags=counts.most_common(70)
tags
# Out:
# [('방문', 164),
#  ('마을', 125),
#  ('아이', 118),
#  ('정말', 113),
#  ('사진', 112),
#  ('사람', 109),
#  ('생각', 94),
#  ('추천', 91),
#  ('산책', 85),
#  ('바다', 84),
#  ('장소', 81),
#  ('가족', 76),
#  ('전망대', 74),
#  ('시간', 72),
#  ('구경', 71),
#  ('한번', 68),
#  ('체험', 67),
#  ('공원', 63),
#  ('시장', 63),
#  ('가면', 62),
#  ('느낌', 61),
#  ('부산', 60),
#  ('서울', 59),
#  ('거리', 59),
#  ('바람', 58),
#  ('근처', 55),
#  ('건물', 52),
#  ('풍경', 50),
#  ('조금', 49),
#  ('여행', 49),
#  ('이용', 46),
#  ('경치', 46),
#  ('코스', 44),
#  ('위치', 43),
#  ('모습', 43),
#  ('보고', 43),
#  ('가장', 42),
#  ('언덕', 42),
#  ('볼거리', 41),
#  ('주변', 41),
#  ('정도', 40),
#  ('하나', 40),
#  ('카페', 40),
#  ('입구', 39),
#  ('날씨', 39),
#  ('주차', 37),
#  ('다른', 37),
#  ('그냥', 36),
#  ('역사', 36),
#  ('식당', 36),
#  ('겨울', 35),
#  ('가게', 34),
#  ('바로', 34),
#  ('매우', 34),
#  ('촬영', 33),
#  ('한국', 33),
#  ('입장료', 33),
#  ('골목', 32),
#  ('가격', 32),
#  ('주차장', 32),
#  ('다만', 31),
#  ('타고', 31),
#  ('경험', 31),
#  ('타워', 31),
#  ('테마', 31),
#  ('보기', 30),
#  ('시설', 30),
#  ('친구', 29),
#  ('먹거리', 29),
#  ('자연', 29)]

# %%
# 불필요한 단어 삭제
tags.remove( ('생각', 94))
tags.remove(('가면', 62))
tags.remove(('느낌', 61))
tags.remove(('가장', 42))
tags.remove(('매우', 34))
tags.remove(('그냥', 36))
tags.remove(('다른', 37))

# %%
from PIL import Image
image=Image.open('cloud_img.jpg')
mask=np.array(image)

# %%
## 워드 클라우드 생성
font_path='C:/Windows/Fonts/HMFMOLD.ttf'
from wordcloud import WordCloud
wordcloud=WordCloud(font_path=font_path,
                   background_color='Black',width=1200,height=800,colormap='spring',mask=mask)

print(dict(tags))
# Out:
# {'방문': 164, '마을': 125, '아이': 118, '정말': 113, '사진': 112, '사람': 109, '추천': 91, '산책': 85, '바다': 84, '장소': 81, '가족': 76, '전망대': 74, '시간': 72, '구경': 71, '한번': 68, '체험': 67, '공원': 63, '시장': 63, '부산': 60, '서울': 59, '거리': 59, '바람': 58, '근처': 55, '건물': 52, '풍경': 50, '조금': 49, '여행': 49, '이용': 46, '경치': 46, '코스': 44, '위치': 43, '모습': 43, '보고': 43, '언덕': 42, '볼거리': 41, '주변': 41, '정도': 40, '하나': 40, '카페': 40, '입구': 39, '날씨': 39, '주차': 37, '역사': 36, '식당': 36, '겨울': 35, '가게': 34, '바로': 34, '촬영': 33, '한국': 33, '입장료': 33, '골목': 32, '가격': 32, '주차장': 32, '다만': 31, '타고': 31, '경험': 31, '타워': 31, '테마': 31, '보기': 30, '시설': 30, '친구': 29, '먹거리': 29, '자연': 29}

# %%
cloud=wordcloud.generate_from_frequencies(dict(tags))
plt.figure(figsize=(12,10))
plt.axis('off')
plt.imshow(cloud)
plt.show()
